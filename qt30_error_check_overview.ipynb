# %% [markdown]
# This notebook provides an introduction/setup for error-reporting on the QT30 corpus.
#
# It would be useful to have a general error-check service that could be run on any corpus or file: most immediately however, there is a need to resolve issues in the data of the corpus QT30 (http://corpora.aifdb.org/qt30), which is on its way to being expanded to QT50 with another 20 episodes, and re-released.
#
# A significant number of errors have been uncovered when trying to run a new set of analytics on the corpus (currently under development, https://github.com/arg-tech/papa), which make more complex use of the graph structure and contents of the text field.
#
# There are a few ways of dividing the error types.
#
# Firstly, errors may be general or corpus-specific. Some of the issues are structural mistakes that should never be found in any IAT data (e.g. missing connections between nodes), while others are specific to QT30 (e.g. text without the in-text timestamps formatted correctly for the corpus standard).
#
# Secondly, errors may be 'visible' errors that can be seen (and therefore corrected) by annotators, such as edges going in the wrong directions. Others are 'invisible', such as markup on the text being for nodes that do not exist elsewhere in the file (and were presumably deleted, but without the text markup updating).
#
# Overall, the conclusion has been that anything fixable by annotators should be fixed by them, rather than automatically by script (even if it's something that *could* be scripted), and only errors that annotators can't fix (like duplicate copies of a node appearing in the JSON) should be passed on to someone with direct database access.
#
# The goal therefore is to produce a comprehensive report of errors that can be then forwarded to the appropriate person/team to fix. It is likely that many of the 'general' errors are already picked up by Erisa's code.
#
# ----
#
# The original solution to the errors was to patch them on a local copy and keep a running tally, but it became clear that the errors were too frequent (albeit trivial) for this to be a practical solution.
#
# Below are some pieces of code used to download the corpus locally and start that patching.

# %%
from tools import ova_combo
from tools import aifdb_fetcher
from src import xaif_toolbox
from src import papa
from src import analytics

import pandas as pd 
import regex as re 
import os
import json
import urllib
import csv
import wget
import importlib
import requests
from glob import glob

# %%
importlib.reload(papa)
# Out:
# <module 'src.papa' from '/Users/eimear/GitHub/papa/src/papa.py'>

# %% [markdown]
# Not all QT30 files are in the current format, some are old and will need converting from OVA2 to OVA3 (function is in xaif_toolbox).
#
# Need to work with the OVA XAIF files not the plain AIF, because need to find issues in the text field as well.

# %% [markdown]
# # Downloading and patching

# %% [markdown]
# Download QT30

# %%
with open('./tests/qt30_test/qt_ep_true_shortnames.csv', 'r', encoding='utf-8-sig') as f:
    qt30_ep_tuples = [tuple(line) for line in csv.reader(f)]
ep_names = [t[1] for t in qt30_ep_tuples]

url = f"http://corpora.aifdb.org/nodesets.php?shortname=qt30"
with urllib.request.urlopen(url) as url:
    nodesets = json.loads(url.read().decode())

with open('./tests/qt30_test/qt30_shortcorps.txt', 'r') as file:
    qt30_episode_list = file.read().splitlines()

# %% [markdown]
# (Haven't made this dir yet, but...)

# %% [markdown]
# Download, and convert any old-format files.

# %%
base_dir = "./qt30_error_finding/orig_episode_maps"
map_type = 'ova'

for shortname, epname in qt30_ep_tuples:
    dir_out = f"{base_dir}/{epname}"
    #os.path.join(base_dir, epname)

    if not os.path.exists(dir_out):
        os.makedirs(dir_out)


    url = f"http://corpora.aifdb.org/nodesets.php?shortname={shortname}"
    with urllib.request.urlopen(url) as url:
        data = json.loads(url.read().decode())
    map_list = data['nodeSets']
    print(f"\nNodesets for {epname}:", data['nodeSets'])
    missing = []
    
    for i, n in enumerate(data['nodeSets']):
        print("----")
        print(f"Checking for argmap at nodeset {n} (node {i+1}/{len(data['nodeSets'])})")
        filepath = f"{dir_out}/{str(n)}.json" #os.path.join(dir_out, f"{str(n)}.json")

        # print(f"Checking for file {filepath}")
        if os.path.exists(filepath):
            pass
            # print("Already downloaded!")
        else:
            # print("File doesn't exist yet.")
            # fileurl = url_base + n
            if map_type == 'ova':
                fileurl = f"http://ova.arg.tech/db/{n}"
                # print(f"\nGetting OVA-friendly file", end='')
            else:
                fileurl = f"http://www.aifdb.org/json/{n}"
                # print(f"\nGetting json file at {fileurl}",  end='')

            print(f" Getting url {fileurl}... ")
            try:
                wget.download(fileurl, filepath)
                print("\nDone")
            except urllib.error.HTTPError:
                missing.append(n)
                print(f"404: Nodeset {n} appears not to exist")
print("----")

for ep in ep_names:
    ova_combo.ova_all_ova3(f'./qt30_error_finding/orig_episode_maps/{ep}', f'./qt30_error_finding/ova3_episode_maps/{ep}')
# Out:
# Nodesets for 11november2021: [23460, 23473, 23475, 23476, 23478, 23479, 23480, 23481, 23483, 23484, 23485, 23487, 23488, 23491, 23494, 23495, 23496, 23497, 23498, 23500, 23502, 23503, 23504, 23505, 23506, 23507, 23508, 23509, 23510, 23511, 23512, 23513, 23514, 23515, 23517, 23555, 23688, 24042, 25475, 25409, 25690, 25691]
# ----
# Checking for argmap at nodeset 23460 (node 1/42)
#  Getting url http://ova.arg.tech/db/23460...
#
# Done
# ----
# Checking for argmap at nodeset 23473 (node 2/42)
#  Getting url http://ova.arg.tech/db/23473...
#
# Done
# ----
# Checking for argmap at nodeset 23475 (node 3/42)
#  Getting url http://ova.arg.tech/db/23475...
#
# Done
# ----
# Checking for argmap at nodeset 23476 (node 4/42)
#  Getting url http://ova.arg.tech/db/23476...
#
# Done
# ----
# Checking for argmap at nodeset 23478 (node 5/42)
#  Getting url http://ova.arg.tech/db/23478...
#
# Done
# ----
# Checking for argmap at nodeset 23479 (node 6/42)
#  Getting url http://ova.arg.tech/db/23479...
#
# Done
# ----
# Checking for argmap at nodeset 23480 (node 7/42)
#  Getting url http://ova.arg.tech/db/23480...
#
# Done
# ----
# Checking for argmap at nodeset 23481 (node 8/42)
#  Getting url http://ova.arg.tech/db/23481...
#
# Done
# ----
# Checking for argmap at nodeset 23483 (node 9/42)
#  Getting url http://ova.arg.tech/db/23483...
#
# Done
# ----
# Checking for argmap at nodeset 23484 (node 10/42)
#  Getting url http://ova.arg.tech/db/23484...
#
# Done
# ----
# Checking for argmap at nodeset 23485 (node 11/42)
#  Getting url http://ova.arg.tech/db/23485...
#
# Done
# ----
# Checking for argmap at nodeset 23487 (node 12/42)
#  Getting url http://ova.arg.tech/db/23487...
#
# Done
# ----
# Checking for argmap at nodeset 23488 (node 13/42)
#  Getting url http://ova.arg.tech/db/23488...
#
# Done
# ----
# Checking for argmap at nodeset 23491 (node 14/42)
#  Getting url http://ova.arg.tech/db/23491...
#
# Done
# ----
# Checking for argmap at nodeset 23494 (node 15/42)
#  Getting url http://ova.arg.tech/db/23494...
#
# Done
# ----
# Checking for argmap at nodeset 23495 (node 16/42)
#  Getting url http://ova.arg.tech/db/23495...
#
# Done
# ----
# Checking for argmap at nodeset 23496 (node 17/42)
#  Getting url http://ova.arg.tech/db/23496...
#
# Done
# ----
# Checking for argmap at nodeset 23497 (node 18/42)
#  Getting url http://ova.arg.tech/db/23497...
#
# Done
# ----
# Checking for argmap at nodeset 23498 (node 19/42)
#  Getting url http://ova.arg.tech/db/23498...
#
# Done
# ----
# Checking for argmap at nodeset 23500 (node 20/42)
#  Getting url http://ova.arg.tech/db/23500...
#
# Done
# ----
# Checking for argmap at nodeset 23502 (node 21/42)
#  Getting url http://ova.arg.tech/db/23502...
#
# Done
# ----
# Checking for argmap at nodeset 23503 (node 22/42)
#  Getting url http://ova.arg.tech/db/23503...
#
# Done
# ----
# Checking for argmap at nodeset 23504 (node 23/42)
#  Getting url http://ova.arg.tech/db/23504...
#
# Done
# ----
# Checking for argmap at nodeset 23505 (node 24/42)
#  Getting url http://ova.arg.tech/db/23505...
#
# Done
# ----
# Checking for argmap at nodeset 23506 (node 25/42)
#  Getting url http://ova.arg.tech/db/23506...
#
# Done
# ----
# Checking for argmap at nodeset 23507 (node 26/42)
#  Getting url http://ova.arg.tech/db/23507...
#
# Done
# ----
# Checking for argmap at nodeset 23508 (node 27/42)
#  Getting url http://ova.arg.tech/db/23508...
#
# Done
# ----
# Checking for argmap at nodeset 23509 (node 28/42)
#  Getting url http://ova.arg.tech/db/23509...
#
# Done
# ----
# Checking for argmap at nodeset 23510 (node 29/42)
#  Getting url http://ova.arg.tech/db/23510...
#
# Done
# ----
# Checking for argmap at nodeset 23511 (node 30/42)
#  Getting url http://ova.arg.tech/db/23511...
#
# Done
# ----
# Checking for argmap at nodeset 23512 (node 31/42)
#  Getting url http://ova.arg.tech/db/23512...
#
# Done
# ----
# Checking for argmap at nodeset 23513 (node 32/42)
#  Getting url http://ova.arg.tech/db/23513...
#
# Done
# ----
# Checking for argmap at nodeset 23514 (node 33/42)
#  Getting url http://ova.arg.tech/db/23514...
#
# Done
# ----
# Checking for argmap at nodeset 23515 (node 34/42)
#  Getting url http://ova.arg.tech/db/23515...
#
# Done
# ----
# Checking for argmap at nodeset 23517 (node 35/42)
#  Getting url http://ova.arg.tech/db/23517...
#
# Done
# ----
# Checking for argmap at nodeset 23555 (node 36/42)
#  Getting url http://ova.arg.tech/db/23555...
#
# Done
# ----
# Checking for argmap at nodeset 23688 (node 37/42)
#  Getting url http://ova.arg.tech/db/23688...
#
# Done
# ----
# Checking for argmap at nodeset 24042 (node 38/42)
#  Getting url http://ova.arg.tech/db/24042...
#
# Done
# ----
# Checking for argmap at nodeset 25475 (node 39/42)
#  Getting url http://ova.arg.tech/db/25475...
# 404: Nodeset 25475 appears not to exist
# ----
# Checking for argmap at nodeset 25409 (node 40/42)
#  Getting url http://ova.arg.tech/db/25409...
#
# Done
# ----
# Checking for argmap at nodeset 25690 (node 41/42)
#  Getting url http://ova.arg.tech/db/25690...
#
# Done
# ----
# Checking for argmap at nodeset 25691 (node 42/42)
#  Getting url http://ova.arg.tech/db/25691...
#
# Done
#
# Nodesets for 28october2021: [23521, 23523, 23525, 23526, 23527, 23530, 23531, 23533, 23535, 23536, 23537, 23538, 23539, 23541, 23542, 23544, 23545, 23547, 23548, 23549, 23550, 23551, 23552, 23553, 23556, 23557, 23558, 23559, 23560, 23561, 23562, 23563, 23565, 23566, 23567, 23569, 23570, 23571, 23572, 23573, 23574, 23575, 23576, 23577, 23578, 23579, 23580, 23581, 23582, 23583, 23584, 23585, 23586, 23587, 23588, 25379, 25474, 23568, 25692]
# ----
# Checking for argmap at nodeset 23521 (node 1/59)
#  Getting url http://ova.arg.tech/db/23521...
#
# Done
# ----
# Checking for argmap at nodeset 23523 (node 2/59)
#  Getting url http://ova.arg.tech/db/23523...
#
# Done
# ----
# Checking for argmap at nodeset 23525 (node 3/59)
#  Getting url http://ova.arg.tech/db/23525...
#
# Done
# ----
# Checking for argmap at nodeset 23526 (node 4/59)
#  Getting url http://ova.arg.tech/db/23526...
#
# Done
# ----
# Checking for argmap at nodeset 23527 (node 5/59)
#  Getting url http://ova.arg.tech/db/23527...
#
# Done
# ----
# Checking for argmap at nodeset 23530 (node 6/59)
#  Getting url http://ova.arg.tech/db/23530...
#
# Done
# ----
# Checking for argmap at nodeset 23531 (node 7/59)
#  Getting url http://ova.arg.tech/db/23531...
#
# Done
# ----
# Checking for argmap at nodeset 23533 (node 8/59)
#  Getting url http://ova.arg.tech/db/23533...
#
# Done
# ----
# Checking for argmap at nodeset 23535 (node 9/59)
#  Getting url http://ova.arg.tech/db/23535...
#
# Done
# ----
# Checking for argmap at nodeset 23536 (node 10/59)
#  Getting url http://ova.arg.tech/db/23536...
#
# Done
# ----
# Checking for argmap at nodeset 23537 (node 11/59)
#  Getting url http://ova.arg.tech/db/23537...
#
# Done
# ----
# Checking for argmap at nodeset 23538 (node 12/59)
#  Getting url http://ova.arg.tech/db/23538...
#
# Done
# ----
# Checking for argmap at nodeset 23539 (node 13/59)
#  Getting url http://ova.arg.tech/db/23539...
#
# Done
# ----
# Checking for argmap at nodeset 23541 (node 14/59)
#  Getting url http://ova.arg.tech/db/23541...
#
# Done
# ----
# Checking for argmap at nodeset 23542 (node 15/59)
#  Getting url http://ova.arg.tech/db/23542...
#
# Done
# ----
# Checking for argmap at nodeset 23544 (node 16/59)
#  Getting url http://ova.arg.tech/db/23544...
#
# Done
# ----
# Checking for argmap at nodeset 23545 (node 17/59)
#  Getting url http://ova.arg.tech/db/23545...
#
# Done
# ----
# Checking for argmap at nodeset 23547 (node 18/59)
#  Getting url http://ova.arg.tech/db/23547...
#
# Done
# ----
# Checking for argmap at nodeset 23548 (node 19/59)
#  Getting url http://ova.arg.tech/db/23548...
#
# Done
# ----
# Checking for argmap at nodeset 23549 (node 20/59)
#  Getting url http://ova.arg.tech/db/23549...
#
# Done
# ----
# Checking for argmap at nodeset 23550 (node 21/59)
#  Getting url http://ova.arg.tech/db/23550...
#
# Done
# ----
# Checking for argmap at nodeset 23551 (node 22/59)
#  Getting url http://ova.arg.tech/db/23551...
#
# Done
# ----
# Checking for argmap at nodeset 23552 (node 23/59)
#  Getting url http://ova.arg.tech/db/23552...
#
# Done
# ----
# Checking for argmap at nodeset 23553 (node 24/59)
#  Getting url http://ova.arg.tech/db/23553...
#
# Done
# ----
# Checking for argmap at nodeset 23556 (node 25/59)
#  Getting url http://ova.arg.tech/db/23556...
#
# Done
# ----
# Checking for argmap at nodeset 23557 (node 26/59)
#  Getting url http://ova.arg.tech/db/23557...
#
# Done
# ----
# Checking for argmap at nodeset 23558 (node 27/59)
#  Getting url http://ova.arg.tech/db/23558...
#
# Done
# ----
# Checking for argmap at nodeset 23559 (node 28/59)
#  Getting url http://ova.arg.tech/db/23559...
#
# Done
# ----
# Checking for argmap at nodeset 23560 (node 29/59)
#  Getting url http://ova.arg.tech/db/23560...
#
# Done
# ----
# Checking for argmap at nodeset 23561 (node 30/59)
#  Getting url http://ova.arg.tech/db/23561...
#
# Done
# ----
# Checking for argmap at nodeset 23562 (node 31/59)
#  Getting url http://ova.arg.tech/db/23562...
#
# Done
# ----
# Checking for argmap at nodeset 23563 (node 32/59)
#  Getting url http://ova.arg.tech/db/23563...
#
# Done
# ----
# Checking for argmap at nodeset 23565 (node 33/59)
#  Getting url http://ova.arg.tech/db/23565...
#
# Done
# ----
# Checking for argmap at nodeset 23566 (node 34/59)
#  Getting url http://ova.arg.tech/db/23566...
#
# Done
# ----
# Checking for argmap at nodeset 23567 (node 35/59)
#  Getting url http://ova.arg.tech/db/23567...
#
# Done
# ----
# Checking for argmap at nodeset 23569 (node 36/59)
#  Getting url http://ova.arg.tech/db/23569...
#
# Done
# ----
# Checking for argmap at nodeset 23570 (node 37/59)
#  Getting url http://ova.arg.tech/db/23570...
#
# Done
# ----
# Checking for argmap at nodeset 23571 (node 38/59)
#  Getting url http://ova.arg.tech/db/23571...
#
# Done
# ----
# Checking for argmap at nodeset 23572 (node 39/59)
#  Getting url http://ova.arg.tech/db/23572...
#
# Done
# ----
# Checking for argmap at nodeset 23573 (node 40/59)
#  Getting url http://ova.arg.tech/db/23573...
#
# Done
# ----
# Checking for argmap at nodeset 23574 (node 41/59)
#  Getting url http://ova.arg.tech/db/23574...
#
# Done
# ----
# Checking for argmap at nodeset 23575 (node 42/59)
#  Getting url http://ova.arg.tech/db/23575...
#
# Done
# ----
# Checking for argmap at nodeset 23576 (node 43/59)
#  Getting url http://ova.arg.tech/db/23576...
#
# Done
# ----
# Checking for argmap at nodeset 23577 (node 44/59)
#  Getting url http://ova.arg.tech/db/23577...
#
# Done
# ----
# Checking for argmap at nodeset 23578 (node 45/59)
#  Getting url http://ova.arg.tech/db/23578...
#
# Done
# ----
# Checking for argmap at nodeset 23579 (node 46/59)
#  Getting url http://ova.arg.tech/db/23579...
#
# Done
# ----
# Checking for argmap at nodeset 23580 (node 47/59)
#  Getting url http://ova.arg.tech/db/23580...
#
# Done
# ----
# Checking for argmap at nodeset 23581 (node 48/59)
#  Getting url http://ova.arg.tech/db/23581...
#
# Done
# ----
# Checking for argmap at nodeset 23582 (node 49/59)
#  Getting url http://ova.arg.tech/db/23582...
#
# Done
# ----
# Checking for argmap at nodeset 23583 (node 50/59)
#  Getting url http://ova.arg.tech/db/23583...
#
# Done
# ----
# Checking for argmap at nodeset 23584 (node 51/59)
#  Getting url http://ova.arg.tech/db/23584...
#
# Done
# ----
# Checking for argmap at nodeset 23585 (node 52/59)
#  Getting url http://ova.arg.tech/db/23585...
#
# Done
# ----
# Checking for argmap at nodeset 23586 (node 53/59)
#  Getting url http://ova.arg.tech/db/23586...
#
# Done
# ----
# Checking for argmap at nodeset 23587 (node 54/59)
#  Getting url http://ova.arg.tech/db/23587...
#
# Done
# ----
# Checking for argmap at nodeset 23588 (node 55/59)
#  Getting url http://ova.arg.tech/db/23588...
#
# Done
# ----
# Checking for argmap at nodeset 25379 (node 56/59)
#  Getting url http://ova.arg.tech/db/25379...
#
# Done
# ----
# Checking for argmap at nodeset 25474 (node 57/59)
#  Getting url http://ova.arg.tech/db/25474...
# 404: Nodeset 25474 appears not to exist
# ----
# Checking for argmap at nodeset 23568 (node 58/59)
#  Getting url http://ova.arg.tech/db/23568...
#
# Done
# ----
# Checking for argmap at nodeset 25692 (node 59/59)
#  Getting url http://ova.arg.tech/db/25692...
#
# Done
#
# Nodesets for 14october2021: [23589, 23590, 23591, 23593, 23594, 23595, 23596, 23597, 23599, 23600, 23601, 23602, 23603, 23604, 23605, 23606, 23607, 23608, 23609, 23610, 23611, 23612, 23613, 23614, 23615, 23616, 23617, 23618, 23620, 23621, 23622, 23623, 23624, 23625, 23626, 23627, 25472, 25693, 25694, 25695]
# ----
# Checking for argmap at nodeset 23589 (node 1/40)
#  Getting url http://ova.arg.tech/db/23589...
#
# Done
# ----
# Checking for argmap at nodeset 23590 (node 2/40)
#  Getting url http://ova.arg.tech/db/23590...
#
# Done
# ----
# Checking for argmap at nodeset 23591 (node 3/40)
#  Getting url http://ova.arg.tech/db/23591...
#
# Done
# ----
# Checking for argmap at nodeset 23593 (node 4/40)
#  Getting url http://ova.arg.tech/db/23593...
#
# Done
# ----
# Checking for argmap at nodeset 23594 (node 5/40)
#  Getting url http://ova.arg.tech/db/23594...
#
# Done
# ----
# Checking for argmap at nodeset 23595 (node 6/40)
#  Getting url http://ova.arg.tech/db/23595...
#
# Done
# ----
# Checking for argmap at nodeset 23596 (node 7/40)
#  Getting url http://ova.arg.tech/db/23596...
#
# Done
# ----
# Checking for argmap at nodeset 23597 (node 8/40)
#  Getting url http://ova.arg.tech/db/23597...
#
# Done
# ----
# Checking for argmap at nodeset 23599 (node 9/40)
#  Getting url http://ova.arg.tech/db/23599...
#
# Done
# ----
# Checking for argmap at nodeset 23600 (node 10/40)
#  Getting url http://ova.arg.tech/db/23600...
#
# Done
# ----
# Checking for argmap at nodeset 23601 (node 11/40)
#  Getting url http://ova.arg.tech/db/23601...
#
# Done
# ----
# Checking for argmap at nodeset 23602 (node 12/40)
#  Getting url http://ova.arg.tech/db/23602...
#
# Done
# ----
# Checking for argmap at nodeset 23603 (node 13/40)
#  Getting url http://ova.arg.tech/db/23603...
#
# Done
# ----
# Checking for argmap at nodeset 23604 (node 14/40)
#  Getting url http://ova.arg.tech/db/23604...
#
# Done
# ----
# Checking for argmap at nodeset 23605 (node 15/40)
#  Getting url http://ova.arg.tech/db/23605...
#
# Done
# ----
# Checking for argmap at nodeset 23606 (node 16/40)
#  Getting url http://ova.arg.tech/db/23606...
#
# Done
# ----
# Checking for argmap at nodeset 23607 (node 17/40)
#  Getting url http://ova.arg.tech/db/23607...
#
# Done
# ----
# Checking for argmap at nodeset 23608 (node 18/40)
#  Getting url http://ova.arg.tech/db/23608...
#
# Done
# ----
# Checking for argmap at nodeset 23609 (node 19/40)
#  Getting url http://ova.arg.tech/db/23609...
#
# Done
# ----
# Checking for argmap at nodeset 23610 (node 20/40)
#  Getting url http://ova.arg.tech/db/23610...
#
# Done
# ----
# Checking for argmap at nodeset 23611 (node 21/40)
#  Getting url http://ova.arg.tech/db/23611...
#
# Done
# ----
# Checking for argmap at nodeset 23612 (node 22/40)
#  Getting url http://ova.arg.tech/db/23612...
#
# Done
# ----
# Checking for argmap at nodeset 23613 (node 23/40)
#  Getting url http://ova.arg.tech/db/23613...
#
# Done
# ----
# Checking for argmap at nodeset 23614 (node 24/40)
#  Getting url http://ova.arg.tech/db/23614...
#
# Done
# ----
# Checking for argmap at nodeset 23615 (node 25/40)
#  Getting url http://ova.arg.tech/db/23615...
#
# Done
# ----
# Checking for argmap at nodeset 23616 (node 26/40)
#  Getting url http://ova.arg.tech/db/23616...
#
# Done
# ----
# Checking for argmap at nodeset 23617 (node 27/40)
#  Getting url http://ova.arg.tech/db/23617...
#
# Done
# ----
# Checking for argmap at nodeset 23618 (node 28/40)
#  Getting url http://ova.arg.tech/db/23618...
#
# Done
# ----
# Checking for argmap at nodeset 23620 (node 29/40)
#  Getting url http://ova.arg.tech/db/23620...
#
# Done
# ----
# Checking for argmap at nodeset 23621 (node 30/40)
#  Getting url http://ova.arg.tech/db/23621...
#
# Done
# ----
# Checking for argmap at nodeset 23622 (node 31/40)
#  Getting url http://ova.arg.tech/db/23622...
#
# Done
# ----
# Checking for argmap at nodeset 23623 (node 32/40)
#  Getting url http://ova.arg.tech/db/23623...
#
# Done
# ----
# Checking for argmap at nodeset 23624 (node 33/40)
#  Getting url http://ova.arg.tech/db/23624...
#
# Done
# ----
# Checking for argmap at nodeset 23625 (node 34/40)
#  Getting url http://ova.arg.tech/db/23625...
#
# Done
# ----
# Checking for argmap at nodeset 23626 (node 35/40)
#  Getting url http://ova.arg.tech/db/23626...
#
# Done
# ----
# Checking for argmap at nodeset 23627 (node 36/40)
#  Getting url http://ova.arg.tech/db/23627...
#
# Done
# ----
# Checking for argmap at nodeset 25472 (node 37/40)
#  Getting url http://ova.arg.tech/db/25472...
# 404: Nodeset 25472 appears not to exist
# ----
# Checking for argmap at nodeset 25693 (node 38/40)
#  Getting url http://ova.arg.tech/db/25693...
#
# Done
# ----
# Checking for argmap at nodeset 25694 (node 39/40)
#  Getting url http://ova.arg.tech/db/25694...
#
# Done
# ----
# Checking for argmap at nodeset 25695 (node 40/40)
#  Getting url http://ova.arg.tech/db/25695...
#
# Done
#
# Nodesets for 30september2021: [23700, 23701, 23702, 23703, 23704, 23705, 23706, 23707, 23708, 23709, 23710, 23711, 23712, 23713, 23715, 23716, 23718, 23719, 23720, 23721, 23722, 23723, 23724, 23725, 23727, 23728, 23729, 23730, 23731, 23732, 23733, 23734, 23735, 23736, 23737, 23738, 23739, 23740, 23741, 23742, 23743, 23744, 23745, 23746, 23747, 23748, 23749, 23750, 23751, 23752, 23753, 23755, 23756, 23757, 23758, 23759, 25045, 25416, 23642]
# ----
# Checking for argmap at nodeset 23700 (node 1/59)
#  Getting url http://ova.arg.tech/db/23700...
#
# Done
# ----
# Checking for argmap at nodeset 23701 (node 2/59)
#  Getting url http://ova.arg.tech/db/23701...
#
# Done
# ----
# Checking for argmap at nodeset 23702 (node 3/59)
#  Getting url http://ova.arg.tech/db/23702...
#
# Done
# ----
# Checking for argmap at nodeset 23703 (node 4/59)
#  Getting url http://ova.arg.tech/db/23703...
#
# Done
# ----
# Checking for argmap at nodeset 23704 (node 5/59)
#  Getting url http://ova.arg.tech/db/23704...
#
# Done
# ----
# Checking for argmap at nodeset 23705 (node 6/59)
#  Getting url http://ova.arg.tech/db/23705...
#
# Done
# ----
# Checking for argmap at nodeset 23706 (node 7/59)
#  Getting url http://ova.arg.tech/db/23706...
#
# Done
# ----
# Checking for argmap at nodeset 23707 (node 8/59)
#  Getting url http://ova.arg.tech/db/23707...
#
# Done
# ----
# Checking for argmap at nodeset 23708 (node 9/59)
#  Getting url http://ova.arg.tech/db/23708...
#
# Done
# ----
# Checking for argmap at nodeset 23709 (node 10/59)
#  Getting url http://ova.arg.tech/db/23709...
#
# Done
# ----
# Checking for argmap at nodeset 23710 (node 11/59)
#  Getting url http://ova.arg.tech/db/23710...
#
# Done
# ----
# Checking for argmap at nodeset 23711 (node 12/59)
#  Getting url http://ova.arg.tech/db/23711...
#
# Done
# ----
# Checking for argmap at nodeset 23712 (node 13/59)
#  Getting url http://ova.arg.tech/db/23712...
#
# Done
# ----
# Checking for argmap at nodeset 23713 (node 14/59)
#  Getting url http://ova.arg.tech/db/23713...
#
# Done
# ----
# Checking for argmap at nodeset 23715 (node 15/59)
#  Getting url http://ova.arg.tech/db/23715...
#
# Done
# ----
# Checking for argmap at nodeset 23716 (node 16/59)
#  Getting url http://ova.arg.tech/db/23716...
#
# Done
# ----
# Checking for argmap at nodeset 23718 (node 17/59)
#  Getting url http://ova.arg.tech/db/23718...
#
# Done
# ----
# Checking for argmap at nodeset 23719 (node 18/59)
#  Getting url http://ova.arg.tech/db/23719...
#
# Done
# ----
# Checking for argmap at nodeset 23720 (node 19/59)
#  Getting url http://ova.arg.tech/db/23720...
#
# Done
# ----
# Checking for argmap at nodeset 23721 (node 20/59)
#  Getting url http://ova.arg.tech/db/23721...
#
# Done
# ----
# Checking for argmap at nodeset 23722 (node 21/59)
#  Getting url http://ova.arg.tech/db/23722...
#
# Done
# ----
# Checking for argmap at nodeset 23723 (node 22/59)
#  Getting url http://ova.arg.tech/db/23723...
#
# Done
# ----
# Checking for argmap at nodeset 23724 (node 23/59)
#  Getting url http://ova.arg.tech/db/23724...
#
# Done
# ----
# Checking for argmap at nodeset 23725 (node 24/59)
#  Getting url http://ova.arg.tech/db/23725...
#
# Done
# ----
# Checking for argmap at nodeset 23727 (node 25/59)
#  Getting url http://ova.arg.tech/db/23727...
#
# Done
# ----
# Checking for argmap at nodeset 23728 (node 26/59)
#  Getting url http://ova.arg.tech/db/23728...
#
# Done
# ----
# Checking for argmap at nodeset 23729 (node 27/59)
#  Getting url http://ova.arg.tech/db/23729...
#
# Done
# ----
# Checking for argmap at nodeset 23730 (node 28/59)
#  Getting url http://ova.arg.tech/db/23730...
#
# Done
# ----
# Checking for argmap at nodeset 23731 (node 29/59)
#  Getting url http://ova.arg.tech/db/23731...
#
# Done
# ----
# Checking for argmap at nodeset 23732 (node 30/59)
#  Getting url http://ova.arg.tech/db/23732...
#
# Done
# ----
# Checking for argmap at nodeset 23733 (node 31/59)
#  Getting url http://ova.arg.tech/db/23733...
#
# Done
# ----
# Checking for argmap at nodeset 23734 (node 32/59)
#  Getting url http://ova.arg.tech/db/23734...
#
# Done
# ----
# Checking for argmap at nodeset 23735 (node 33/59)
#  Getting url http://ova.arg.tech/db/23735...
#
# Done
# ----
# Checking for argmap at nodeset 23736 (node 34/59)
#  Getting url http://ova.arg.tech/db/23736...
#
# Done
# ----
# Checking for argmap at nodeset 23737 (node 35/59)
#  Getting url http://ova.arg.tech/db/23737...
#
# Done
# ----
# Checking for argmap at nodeset 23738 (node 36/59)
#  Getting url http://ova.arg.tech/db/23738...
#
# Done
# ----
# Checking for argmap at nodeset 23739 (node 37/59)
#  Getting url http://ova.arg.tech/db/23739...
#
# Done
# ----
# Checking for argmap at nodeset 23740 (node 38/59)
#  Getting url http://ova.arg.tech/db/23740...
#
# Done
# ----
# Checking for argmap at nodeset 23741 (node 39/59)
#  Getting url http://ova.arg.tech/db/23741...
#
# Done
# ----
# Checking for argmap at nodeset 23742 (node 40/59)
#  Getting url http://ova.arg.tech/db/23742...
#
# Done
# ----
# Checking for argmap at nodeset 23743 (node 41/59)
#  Getting url http://ova.arg.tech/db/23743...
#
# Done
# ----
# Checking for argmap at nodeset 23744 (node 42/59)
#  Getting url http://ova.arg.tech/db/23744...
#
# Done
# ----
# Checking for argmap at nodeset 23745 (node 43/59)
#  Getting url http://ova.arg.tech/db/23745...
#
# Done
# ----
# Checking for argmap at nodeset 23746 (node 44/59)
#  Getting url http://ova.arg.tech/db/23746...
#
# Done
# ----
# Checking for argmap at nodeset 23747 (node 45/59)
#  Getting url http://ova.arg.tech/db/23747...
#
# Done
# ----
# Checking for argmap at nodeset 23748 (node 46/59)
#  Getting url http://ova.arg.tech/db/23748...
#
# Done
# ----
# Checking for argmap at nodeset 23749 (node 47/59)
#  Getting url http://ova.arg.tech/db/23749...
#
# Done
# ----
# Checking for argmap at nodeset 23750 (node 48/59)
#  Getting url http://ova.arg.tech/db/23750...
#
# Done
# ----
# Checking for argmap at nodeset 23751 (node 49/59)
#  Getting url http://ova.arg.tech/db/23751...
#
# Done
# ----
# Checking for argmap at nodeset 23752 (node 50/59)
#  Getting url http://ova.arg.tech/db/23752...
#
# Done
# ----
# Checking for argmap at nodeset 23753 (node 51/59)
#  Getting url http://ova.arg.tech/db/23753...
#
# Done
# ----
# Checking for argmap at nodeset 23755 (node 52/59)
#  Getting url http://ova.arg.tech/db/23755...
#
# Done
# ----
# Checking for argmap at nodeset 23756 (node 53/59)
#  Getting url http://ova.arg.tech/db/23756...
#
# Done
# ----
# Checking for argmap at nodeset 23757 (node 54/59)
#  Getting url http://ova.arg.tech/db/23757...
#
# Done
# ----
# Checking for argmap at nodeset 23758 (node 55/59)
#  Getting url http://ova.arg.tech/db/23758...
#
# Done
# ----
# Checking for argmap at nodeset 23759 (node 56/59)
#  Getting url http://ova.arg.tech/db/23759...
#
# Done
# ----
# Checking for argmap at nodeset 25045 (node 57/59)
#  Getting url http://ova.arg.tech/db/25045...
# 404: Nodeset 25045 appears not to exist
# ----
# Checking for argmap at nodeset 25416 (node 58/59)
#  Getting url http://ova.arg.tech/db/25416...
#
# Done
# ----
# Checking for argmap at nodeset 23642 (node 59/59)
#  Getting url http://ova.arg.tech/db/23642...
#
# Done
#
# Nodesets for 16september2021: [23686, 23690, 23691, 23692, 23694, 23695, 23696, 23698, 23699, 23760, 23761, 23762, 23763, 23765, 23766, 23767, 23768, 23769, 23770, 23771, 23772, 23773, 23774, 23775, 23776, 23777, 23778, 23779, 23780, 23781, 23782, 23783, 23784, 23785, 23786, 23787, 23788, 23789, 23790, 23791, 23792, 23794, 23795, 25473, 25722, 25723, 25724, 25907]
# ----
# Checking for argmap at nodeset 23686 (node 1/48)
#  Getting url http://ova.arg.tech/db/23686...
#
# Done
# ----
# Checking for argmap at nodeset 23690 (node 2/48)
#  Getting url http://ova.arg.tech/db/23690...
#
# Done
# ----
# Checking for argmap at nodeset 23691 (node 3/48)
#  Getting url http://ova.arg.tech/db/23691...
#
# Done
# ----
# Checking for argmap at nodeset 23692 (node 4/48)
#  Getting url http://ova.arg.tech/db/23692...
#
# Done
# ----
# Checking for argmap at nodeset 23694 (node 5/48)
#  Getting url http://ova.arg.tech/db/23694...
#
# Done
# ----
# Checking for argmap at nodeset 23695 (node 6/48)
#  Getting url http://ova.arg.tech/db/23695...
#
# Done
# ----
# Checking for argmap at nodeset 23696 (node 7/48)
#  Getting url http://ova.arg.tech/db/23696...
#
# Done
# ----
# Checking for argmap at nodeset 23698 (node 8/48)
#  Getting url http://ova.arg.tech/db/23698...
#
# Done
# ----
# Checking for argmap at nodeset 23699 (node 9/48)
#  Getting url http://ova.arg.tech/db/23699...
#
# Done
# ----
# Checking for argmap at nodeset 23760 (node 10/48)
#  Getting url http://ova.arg.tech/db/23760...
#
# Done
# ----
# Checking for argmap at nodeset 23761 (node 11/48)
#  Getting url http://ova.arg.tech/db/23761...
#
# Done
# ----
# Checking for argmap at nodeset 23762 (node 12/48)
#  Getting url http://ova.arg.tech/db/23762...
#
# Done
# ----
# Checking for argmap at nodeset 23763 (node 13/48)
#  Getting url http://ova.arg.tech/db/23763...
#
# Done
# ----
# Checking for argmap at nodeset 23765 (node 14/48)
#  Getting url http://ova.arg.tech/db/23765...
#
# Done
# ----
# Checking for argmap at nodeset 23766 (node 15/48)
#  Getting url http://ova.arg.tech/db/23766...
#
# Done
# ----
# Checking for argmap at nodeset 23767 (node 16/48)
#  Getting url http://ova.arg.tech/db/23767...
#
# Done
# ----
# Checking for argmap at nodeset 23768 (node 17/48)
#  Getting url http://ova.arg.tech/db/23768...
#
# Done
# ----
# Checking for argmap at nodeset 23769 (node 18/48)
#  Getting url http://ova.arg.tech/db/23769...
#
# Done
# ----
# Checking for argmap at nodeset 23770 (node 19/48)
#  Getting url http://ova.arg.tech/db/23770...
#
# Done
# ----
# Checking for argmap at nodeset 23771 (node 20/48)
#  Getting url http://ova.arg.tech/db/23771...
#
# Done
# ----
# Checking for argmap at nodeset 23772 (node 21/48)
#  Getting url http://ova.arg.tech/db/23772...
#
# Done
# ----
# Checking for argmap at nodeset 23773 (node 22/48)
#  Getting url http://ova.arg.tech/db/23773...
#
# Done
# ----
# Checking for argmap at nodeset 23774 (node 23/48)
#  Getting url http://ova.arg.tech/db/23774...
#
# Done
# ----
# Checking for argmap at nodeset 23775 (node 24/48)
#  Getting url http://ova.arg.tech/db/23775...
#
# Done
# ----
# Checking for argmap at nodeset 23776 (node 25/48)
#  Getting url http://ova.arg.tech/db/23776...
#
# Done
# ----
# Checking for argmap at nodeset 23777 (node 26/48)
#  Getting url http://ova.arg.tech/db/23777...
#
# Done
# ----
# Checking for argmap at nodeset 23778 (node 27/48)
#  Getting url http://ova.arg.tech/db/23778...
#
# Done
# ----
# Checking for argmap at nodeset 23779 (node 28/48)
#  Getting url http://ova.arg.tech/db/23779...
#
# Done
# ----
# Checking for argmap at nodeset 23780 (node 29/48)
#  Getting url http://ova.arg.tech/db/23780...
#
# Done
# ----
# Checking for argmap at nodeset 23781 (node 30/48)
#  Getting url http://ova.arg.tech/db/23781...
#
# Done
# ----
# Checking for argmap at nodeset 23782 (node 31/48)
#  Getting url http://ova.arg.tech/db/23782...
#
# Done
# ----
# Checking for argmap at nodeset 23783 (node 32/48)
#  Getting url http://ova.arg.tech/db/23783...
#
# Done
# ----
# Checking for argmap at nodeset 23784 (node 33/48)
#  Getting url http://ova.arg.tech/db/23784...
#
# Done
# ----
# Checking for argmap at nodeset 23785 (node 34/48)
#  Getting url http://ova.arg.tech/db/23785...
#
# Done
# ----
# Checking for argmap at nodeset 23786 (node 35/48)
#  Getting url http://ova.arg.tech/db/23786...
#
# Done
# ----
# Checking for argmap at nodeset 23787 (node 36/48)
#  Getting url http://ova.arg.tech/db/23787...
#
# Done
# ----
# Checking for argmap at nodeset 23788 (node 37/48)
#  Getting url http://ova.arg.tech/db/23788...
#
# Done
# ----
# Checking for argmap at nodeset 23789 (node 38/48)
#  Getting url http://ova.arg.tech/db/23789...
#
# Done
# ----
# Checking for argmap at nodeset 23790 (node 39/48)
#  Getting url http://ova.arg.tech/db/23790...
#
# Done
# ----
# Checking for argmap at nodeset 23791 (node 40/48)
#  Getting url http://ova.arg.tech/db/23791...
#
# Done
# ----
# Checking for argmap at nodeset 23792 (node 41/48)
#  Getting url http://ova.arg.tech/db/23792...
#
# Done
# ----
# Checking for argmap at nodeset 23794 (node 42/48)
#  Getting url http://ova.arg.tech/db/23794...
#
# Done
# ----
# Checking for argmap at nodeset 23795 (node 43/48)
#  Getting url http://ova.arg.tech/db/23795...
#
# Done
# ----
# Checking for argmap at nodeset 25473 (node 44/48)
#  Getting url http://ova.arg.tech/db/25473...
# 404: Nodeset 25473 appears not to exist
# ----
# Checking for argmap at nodeset 25722 (node 45/48)
#  Getting url http://ova.arg.tech/db/25722...
#
# Done
# ----
# Checking for argmap at nodeset 25723 (node 46/48)
#  Getting url http://ova.arg.tech/db/25723...
#
# Done
# ----
# Checking for argmap at nodeset 25724 (node 47/48)
#  Getting url http://ova.arg.tech/db/25724...
#
# Done
# ----
# Checking for argmap at nodeset 25907 (node 48/48)
#  Getting url http://ova.arg.tech/db/25907...
#
# Done
#
# Nodesets for 2september2021: [23796, 23797, 23798, 23799, 23800, 23801, 23802, 23803, 23804, 23805, 23806, 23807, 23808, 23809, 23810, 23811, 23812, 23813, 23814, 23815, 23816, 23817, 23818, 23820, 23821, 23822, 23823, 23824, 23825, 23826, 23827, 23828, 23830, 23832, 23834, 23836, 23837, 23838, 23839, 25382, 25383, 25384, 25468, 25726]
# ----
# Checking for argmap at nodeset 23796 (node 1/44)
#  Getting url http://ova.arg.tech/db/23796...
#
# Done
# ----
# Checking for argmap at nodeset 23797 (node 2/44)
#  Getting url http://ova.arg.tech/db/23797...
#
# Done
# ----
# Checking for argmap at nodeset 23798 (node 3/44)
#  Getting url http://ova.arg.tech/db/23798...
#
# Done
# ----
# Checking for argmap at nodeset 23799 (node 4/44)
#  Getting url http://ova.arg.tech/db/23799...
#
# Done
# ----
# Checking for argmap at nodeset 23800 (node 5/44)
#  Getting url http://ova.arg.tech/db/23800...
#
# Done
# ----
# Checking for argmap at nodeset 23801 (node 6/44)
#  Getting url http://ova.arg.tech/db/23801...
#
# Done
# ----
# Checking for argmap at nodeset 23802 (node 7/44)
#  Getting url http://ova.arg.tech/db/23802...
#
# Done
# ----
# Checking for argmap at nodeset 23803 (node 8/44)
#  Getting url http://ova.arg.tech/db/23803...
#
# Done
# ----
# Checking for argmap at nodeset 23804 (node 9/44)
#  Getting url http://ova.arg.tech/db/23804...
#
# Done
# ----
# Checking for argmap at nodeset 23805 (node 10/44)
#  Getting url http://ova.arg.tech/db/23805...
#
# Done
# ----
# Checking for argmap at nodeset 23806 (node 11/44)
#  Getting url http://ova.arg.tech/db/23806...
#
# Done
# ----
# Checking for argmap at nodeset 23807 (node 12/44)
#  Getting url http://ova.arg.tech/db/23807...
#
# Done
# ----
# Checking for argmap at nodeset 23808 (node 13/44)
#  Getting url http://ova.arg.tech/db/23808...
#
# Done
# ----
# Checking for argmap at nodeset 23809 (node 14/44)
#  Getting url http://ova.arg.tech/db/23809...
#
# Done
# ----
# Checking for argmap at nodeset 23810 (node 15/44)
#  Getting url http://ova.arg.tech/db/23810...
#
# Done
# ----
# Checking for argmap at nodeset 23811 (node 16/44)
#  Getting url http://ova.arg.tech/db/23811...
#
# Done
# ----
# Checking for argmap at nodeset 23812 (node 17/44)
#  Getting url http://ova.arg.tech/db/23812...
#
# Done
# ----
# Checking for argmap at nodeset 23813 (node 18/44)
#  Getting url http://ova.arg.tech/db/23813...
#
# Done
# ----
# Checking for argmap at nodeset 23814 (node 19/44)
#  Getting url http://ova.arg.tech/db/23814...
#
# Done
# ----
# Checking for argmap at nodeset 23815 (node 20/44)
#  Getting url http://ova.arg.tech/db/23815...
#
# Done
# ----
# Checking for argmap at nodeset 23816 (node 21/44)
#  Getting url http://ova.arg.tech/db/23816...
#
# Done
# ----
# Checking for argmap at nodeset 23817 (node 22/44)
#  Getting url http://ova.arg.tech/db/23817...
#
# Done
# ----
# Checking for argmap at nodeset 23818 (node 23/44)
#  Getting url http://ova.arg.tech/db/23818...
#
# Done
# ----
# Checking for argmap at nodeset 23820 (node 24/44)
#  Getting url http://ova.arg.tech/db/23820...
#
# Done
# ----
# Checking for argmap at nodeset 23821 (node 25/44)
#  Getting url http://ova.arg.tech/db/23821...
#
# Done
# ----
# Checking for argmap at nodeset 23822 (node 26/44)
#  Getting url http://ova.arg.tech/db/23822...
#
# Done
# ----
# Checking for argmap at nodeset 23823 (node 27/44)
#  Getting url http://ova.arg.tech/db/23823...
#
# Done
# ----
# Checking for argmap at nodeset 23824 (node 28/44)
#  Getting url http://ova.arg.tech/db/23824...
#
# Done
# ----
# Checking for argmap at nodeset 23825 (node 29/44)
#  Getting url http://ova.arg.tech/db/23825...
#
# Done
# ----
# Checking for argmap at nodeset 23826 (node 30/44)
#  Getting url http://ova.arg.tech/db/23826...
#
# Done
# ----
# Checking for argmap at nodeset 23827 (node 31/44)
#  Getting url http://ova.arg.tech/db/23827...
#
# Done
# ----
# Checking for argmap at nodeset 23828 (node 32/44)
#  Getting url http://ova.arg.tech/db/23828...
#
# Done
# ----
# Checking for argmap at nodeset 23830 (node 33/44)
#  Getting url http://ova.arg.tech/db/23830...
#
# Done
# ----
# Checking for argmap at nodeset 23832 (node 34/44)
#  Getting url http://ova.arg.tech/db/23832...
#
# Done
# ----
# Checking for argmap at nodeset 23834 (node 35/44)
#  Getting url http://ova.arg.tech/db/23834...
#
# Done
# ----
# Checking for argmap at nodeset 23836 (node 36/44)
#  Getting url http://ova.arg.tech/db/23836...
#
# Done
# ----
# Checking for argmap at nodeset 23837 (node 37/44)
#  Getting url http://ova.arg.tech/db/23837...
#
# Done
# ----
# Checking for argmap at nodeset 23838 (node 38/44)
#  Getting url http://ova.arg.tech/db/23838...
#
# Done
# ----
# Checking for argmap at nodeset 23839 (node 39/44)
#  Getting url http://ova.arg.tech/db/23839...
#
# Done
# ----
# Checking for argmap at nodeset 25382 (node 40/44)
#  Getting url http://ova.arg.tech/db/25382...
#
# Done
# ----
# Checking for argmap at nodeset 25383 (node 41/44)
#  Getting url http://ova.arg.tech/db/25383...
#
# Done
# ----
# Checking for argmap at nodeset 25384 (node 42/44)
#  Getting url http://ova.arg.tech/db/25384...
#
# Done
# ----
# Checking for argmap at nodeset 25468 (node 43/44)
#  Getting url http://ova.arg.tech/db/25468...
# 404: Nodeset 25468 appears not to exist
# ----
# Checking for argmap at nodeset 25726 (node 44/44)
#  Getting url http://ova.arg.tech/db/25726...
#
# Done
#
# Nodesets for 19august2021: [23841, 23842, 23843, 23844, 23845, 23846, 23847, 23848, 23849, 23850, 23851, 23852, 23853, 23854, 23855, 23857, 23858, 23859, 23860, 23861, 23862, 23863, 23864, 23865, 23866, 23867, 23868, 23869, 23870, 23874, 23875, 23876, 23877, 23878, 23879, 23880, 23881, 25390, 25391, 25465, 25727, 25906]
# ----
# Checking for argmap at nodeset 23841 (node 1/42)
#  Getting url http://ova.arg.tech/db/23841...
#
# Done
# ----
# Checking for argmap at nodeset 23842 (node 2/42)
#  Getting url http://ova.arg.tech/db/23842...
#
# Done
# ----
# Checking for argmap at nodeset 23843 (node 3/42)
#  Getting url http://ova.arg.tech/db/23843...
#
# Done
# ----
# Checking for argmap at nodeset 23844 (node 4/42)
#  Getting url http://ova.arg.tech/db/23844...
#
# Done
# ----
# Checking for argmap at nodeset 23845 (node 5/42)
#  Getting url http://ova.arg.tech/db/23845...
#
# Done
# ----
# Checking for argmap at nodeset 23846 (node 6/42)
#  Getting url http://ova.arg.tech/db/23846...
#
# Done
# ----
# Checking for argmap at nodeset 23847 (node 7/42)
#  Getting url http://ova.arg.tech/db/23847...
#
# Done
# ----
# Checking for argmap at nodeset 23848 (node 8/42)
#  Getting url http://ova.arg.tech/db/23848...
#
# Done
# ----
# Checking for argmap at nodeset 23849 (node 9/42)
#  Getting url http://ova.arg.tech/db/23849...
#
# Done
# ----
# Checking for argmap at nodeset 23850 (node 10/42)
#  Getting url http://ova.arg.tech/db/23850...
#
# Done
# ----
# Checking for argmap at nodeset 23851 (node 11/42)
#  Getting url http://ova.arg.tech/db/23851...
#
# Done
# ----
# Checking for argmap at nodeset 23852 (node 12/42)
#  Getting url http://ova.arg.tech/db/23852...
#
# Done
# ----
# Checking for argmap at nodeset 23853 (node 13/42)
#  Getting url http://ova.arg.tech/db/23853...
#
# Done
# ----
# Checking for argmap at nodeset 23854 (node 14/42)
#  Getting url http://ova.arg.tech/db/23854...
#
# Done
# ----
# Checking for argmap at nodeset 23855 (node 15/42)
#  Getting url http://ova.arg.tech/db/23855...
#
# Done
# ----
# Checking for argmap at nodeset 23857 (node 16/42)
#  Getting url http://ova.arg.tech/db/23857...
#
# Done
# ----
# Checking for argmap at nodeset 23858 (node 17/42)
#  Getting url http://ova.arg.tech/db/23858...
#
# Done
# ----
# Checking for argmap at nodeset 23859 (node 18/42)
#  Getting url http://ova.arg.tech/db/23859...
#
# Done
# ----
# Checking for argmap at nodeset 23860 (node 19/42)
#  Getting url http://ova.arg.tech/db/23860...
#
# Done
# ----
# Checking for argmap at nodeset 23861 (node 20/42)
#  Getting url http://ova.arg.tech/db/23861...
#
# Done
# ----
# Checking for argmap at nodeset 23862 (node 21/42)
#  Getting url http://ova.arg.tech/db/23862...
#
# Done
# ----
# Checking for argmap at nodeset 23863 (node 22/42)
#  Getting url http://ova.arg.tech/db/23863...
#
# Done
# ----
# Checking for argmap at nodeset 23864 (node 23/42)
#  Getting url http://ova.arg.tech/db/23864...
#
# Done
# ----
# Checking for argmap at nodeset 23865 (node 24/42)
#  Getting url http://ova.arg.tech/db/23865...
#
# Done
# ----
# Checking for argmap at nodeset 23866 (node 25/42)
#  Getting url http://ova.arg.tech/db/23866...
#
# Done
# ----
# Checking for argmap at nodeset 23867 (node 26/42)
#  Getting url http://ova.arg.tech/db/23867...
#
# Done
# ----
# Checking for argmap at nodeset 23868 (node 27/42)
#  Getting url http://ova.arg.tech/db/23868...
#
# Done
# ----
# Checking for argmap at nodeset 23869 (node 28/42)
#  Getting url http://ova.arg.tech/db/23869...
#
# Done
# ----
# Checking for argmap at nodeset 23870 (node 29/42)
#  Getting url http://ova.arg.tech/db/23870...
#
# Done
# ----
# Checking for argmap at nodeset 23874 (node 30/42)
#  Getting url http://ova.arg.tech/db/23874...
#
# Done
# ----
# Checking for argmap at nodeset 23875 (node 31/42)
#  Getting url http://ova.arg.tech/db/23875...
#
# Done
# ----
# Checking for argmap at nodeset 23876 (node 32/42)
#  Getting url http://ova.arg.tech/db/23876...
#
# Done
# ----
# Checking for argmap at nodeset 23877 (node 33/42)
#  Getting url http://ova.arg.tech/db/23877...
#
# Done
# ----
# Checking for argmap at nodeset 23878 (node 34/42)
#  Getting url http://ova.arg.tech/db/23878...
#
# Done
# ----
# Checking for argmap at nodeset 23879 (node 35/42)
#  Getting url http://ova.arg.tech/db/23879...
#
# Done
# ----
# Checking for argmap at nodeset 23880 (node 36/42)
#  Getting url http://ova.arg.tech/db/23880...
#
# Done
# ----
# Checking for argmap at nodeset 23881 (node 37/42)
#  Getting url http://ova.arg.tech/db/23881...
#
# Done
# ----
# Checking for argmap at nodeset 25390 (node 38/42)
#  Getting url http://ova.arg.tech/db/25390...
#
# Done
# ----
# Checking for argmap at nodeset 25391 (node 39/42)
#  Getting url http://ova.arg.tech/db/25391...
#
# Done
# ----
# Checking for argmap at nodeset 25465 (node 40/42)
#  Getting url http://ova.arg.tech/db/25465...
# 404: Nodeset 25465 appears not to exist
# ----
# Checking for argmap at nodeset 25727 (node 41/42)
#  Getting url http://ova.arg.tech/db/25727...
#
# Done
# ----
# Checking for argmap at nodeset 25906 (node 42/42)
#  Getting url http://ova.arg.tech/db/25906...
#
# Done
#
# Nodesets for 5august2021: [23883, 23884, 23886, 23887, 23888, 23889, 23890, 23891, 23892, 23893, 23894, 23895, 23896, 23897, 23898, 23900, 23901, 23902, 23904, 23905, 23906, 23907, 23908, 23910, 23911, 23912, 23913, 23914, 23915, 23917, 23918, 23920, 23922, 23923, 23924, 23925, 23926, 23927, 24992, 25433, 25434, 25506, 25728, 25750, 25904]
# ----
# Checking for argmap at nodeset 23883 (node 1/45)
#  Getting url http://ova.arg.tech/db/23883...
#
# Done
# ----
# Checking for argmap at nodeset 23884 (node 2/45)
#  Getting url http://ova.arg.tech/db/23884...
#
# Done
# ----
# Checking for argmap at nodeset 23886 (node 3/45)
#  Getting url http://ova.arg.tech/db/23886...
#
# Done
# ----
# Checking for argmap at nodeset 23887 (node 4/45)
#  Getting url http://ova.arg.tech/db/23887...
#
# Done
# ----
# Checking for argmap at nodeset 23888 (node 5/45)
#  Getting url http://ova.arg.tech/db/23888...
#
# Done
# ----
# Checking for argmap at nodeset 23889 (node 6/45)
#  Getting url http://ova.arg.tech/db/23889...
#
# Done
# ----
# Checking for argmap at nodeset 23890 (node 7/45)
#  Getting url http://ova.arg.tech/db/23890...
#
# Done
# ----
# Checking for argmap at nodeset 23891 (node 8/45)
#  Getting url http://ova.arg.tech/db/23891...
#
# Done
# ----
# Checking for argmap at nodeset 23892 (node 9/45)
#  Getting url http://ova.arg.tech/db/23892...
#
# Done
# ----
# Checking for argmap at nodeset 23893 (node 10/45)
#  Getting url http://ova.arg.tech/db/23893...
#
# Done
# ----
# Checking for argmap at nodeset 23894 (node 11/45)
#  Getting url http://ova.arg.tech/db/23894...
#
# Done
# ----
# Checking for argmap at nodeset 23895 (node 12/45)
#  Getting url http://ova.arg.tech/db/23895...
#
# Done
# ----
# Checking for argmap at nodeset 23896 (node 13/45)
#  Getting url http://ova.arg.tech/db/23896...
#
# Done
# ----
# Checking for argmap at nodeset 23897 (node 14/45)
#  Getting url http://ova.arg.tech/db/23897...
#
# Done
# ----
# Checking for argmap at nodeset 23898 (node 15/45)
#  Getting url http://ova.arg.tech/db/23898...
#
# Done
# ----
# Checking for argmap at nodeset 23900 (node 16/45)
#  Getting url http://ova.arg.tech/db/23900...
#
# Done
# ----
# Checking for argmap at nodeset 23901 (node 17/45)
#  Getting url http://ova.arg.tech/db/23901...
#
# Done
# ----
# Checking for argmap at nodeset 23902 (node 18/45)
#  Getting url http://ova.arg.tech/db/23902...
#
# Done
# ----
# Checking for argmap at nodeset 23904 (node 19/45)
#  Getting url http://ova.arg.tech/db/23904...
#
# Done
# ----
# Checking for argmap at nodeset 23905 (node 20/45)
#  Getting url http://ova.arg.tech/db/23905...
#
# Done
# ----
# Checking for argmap at nodeset 23906 (node 21/45)
#  Getting url http://ova.arg.tech/db/23906...
#
# Done
# ----
# Checking for argmap at nodeset 23907 (node 22/45)
#  Getting url http://ova.arg.tech/db/23907...
#
# Done
# ----
# Checking for argmap at nodeset 23908 (node 23/45)
#  Getting url http://ova.arg.tech/db/23908...
#
# Done
# ----
# Checking for argmap at nodeset 23910 (node 24/45)
#  Getting url http://ova.arg.tech/db/23910...
#
# Done
# ----
# Checking for argmap at nodeset 23911 (node 25/45)
#  Getting url http://ova.arg.tech/db/23911...
#
# Done
# ----
# Checking for argmap at nodeset 23912 (node 26/45)
#  Getting url http://ova.arg.tech/db/23912...
#
# Done
# ----
# Checking for argmap at nodeset 23913 (node 27/45)
#  Getting url http://ova.arg.tech/db/23913...
#
# Done
# ----
# Checking for argmap at nodeset 23914 (node 28/45)
#  Getting url http://ova.arg.tech/db/23914...
#
# Done
# ----
# Checking for argmap at nodeset 23915 (node 29/45)
#  Getting url http://ova.arg.tech/db/23915...
#
# Done
# ----
# Checking for argmap at nodeset 23917 (node 30/45)
#  Getting url http://ova.arg.tech/db/23917...
#
# Done
# ----
# Checking for argmap at nodeset 23918 (node 31/45)
#  Getting url http://ova.arg.tech/db/23918...
#
# Done
# ----
# Checking for argmap at nodeset 23920 (node 32/45)
#  Getting url http://ova.arg.tech/db/23920...
#
# Done
# ----
# Checking for argmap at nodeset 23922 (node 33/45)
#  Getting url http://ova.arg.tech/db/23922...
#
# Done
# ----
# Checking for argmap at nodeset 23923 (node 34/45)
#  Getting url http://ova.arg.tech/db/23923...
#
# Done
# ----
# Checking for argmap at nodeset 23924 (node 35/45)
#  Getting url http://ova.arg.tech/db/23924...
#
# Done
# ----
# Checking for argmap at nodeset 23925 (node 36/45)
#  Getting url http://ova.arg.tech/db/23925...
#
# Done
# ----
# Checking for argmap at nodeset 23926 (node 37/45)
#  Getting url http://ova.arg.tech/db/23926...
#
# Done
# ----
# Checking for argmap at nodeset 23927 (node 38/45)
#  Getting url http://ova.arg.tech/db/23927...
#
# Done
# ----
# Checking for argmap at nodeset 24992 (node 39/45)
#  Getting url http://ova.arg.tech/db/24992...
# 404: Nodeset 24992 appears not to exist
# ----
# Checking for argmap at nodeset 25433 (node 40/45)
#  Getting url http://ova.arg.tech/db/25433...
#
# Done
# ----
# Checking for argmap at nodeset 25434 (node 41/45)
#  Getting url http://ova.arg.tech/db/25434...
#
# Done
# ----
# Checking for argmap at nodeset 25506 (node 42/45)
#  Getting url http://ova.arg.tech/db/25506...
#
# Done
# ----
# Checking for argmap at nodeset 25728 (node 43/45)
#  Getting url http://ova.arg.tech/db/25728...
#
# Done
# ----
# Checking for argmap at nodeset 25750 (node 44/45)
#  Getting url http://ova.arg.tech/db/25750...
#
# Done
# ----
# Checking for argmap at nodeset 25904 (node 45/45)
#  Getting url http://ova.arg.tech/db/25904...
#
# Done
#
# Nodesets for 22july2021: [23928, 23929, 23930, 23931, 23932, 23933, 23934, 23935, 23936, 23938, 23939, 23940, 23941, 23942, 23944, 23947, 23948, 23949, 23950, 23951, 23953, 23954, 23955, 23956, 23958, 23959, 23960, 23961, 23962, 23963, 23965, 23966, 23967, 23968, 23969, 23971, 23972, 23973, 23976, 23388, 23391, 23396, 23398, 25394, 25463, 25729, 25396, 25730, 26066]
# ----
# Checking for argmap at nodeset 23928 (node 1/49)
#  Getting url http://ova.arg.tech/db/23928...
#
# Done
# ----
# Checking for argmap at nodeset 23929 (node 2/49)
#  Getting url http://ova.arg.tech/db/23929...
#
# Done
# ----
# Checking for argmap at nodeset 23930 (node 3/49)
#  Getting url http://ova.arg.tech/db/23930...
#
# Done
# ----
# Checking for argmap at nodeset 23931 (node 4/49)
#  Getting url http://ova.arg.tech/db/23931...
#
# Done
# ----
# Checking for argmap at nodeset 23932 (node 5/49)
#  Getting url http://ova.arg.tech/db/23932...
#
# Done
# ----
# Checking for argmap at nodeset 23933 (node 6/49)
#  Getting url http://ova.arg.tech/db/23933...
#
# Done
# ----
# Checking for argmap at nodeset 23934 (node 7/49)
#  Getting url http://ova.arg.tech/db/23934...
#
# Done
# ----
# Checking for argmap at nodeset 23935 (node 8/49)
#  Getting url http://ova.arg.tech/db/23935...
#
# Done
# ----
# Checking for argmap at nodeset 23936 (node 9/49)
#  Getting url http://ova.arg.tech/db/23936...
#
# Done
# ----
# Checking for argmap at nodeset 23938 (node 10/49)
#  Getting url http://ova.arg.tech/db/23938...
#
# Done
# ----
# Checking for argmap at nodeset 23939 (node 11/49)
#  Getting url http://ova.arg.tech/db/23939...
#
# Done
# ----
# Checking for argmap at nodeset 23940 (node 12/49)
#  Getting url http://ova.arg.tech/db/23940...
#
# Done
# ----
# Checking for argmap at nodeset 23941 (node 13/49)
#  Getting url http://ova.arg.tech/db/23941...
#
# Done
# ----
# Checking for argmap at nodeset 23942 (node 14/49)
#  Getting url http://ova.arg.tech/db/23942...
#
# Done
# ----
# Checking for argmap at nodeset 23944 (node 15/49)
#  Getting url http://ova.arg.tech/db/23944...
#
# Done
# ----
# Checking for argmap at nodeset 23947 (node 16/49)
#  Getting url http://ova.arg.tech/db/23947...
#
# Done
# ----
# Checking for argmap at nodeset 23948 (node 17/49)
#  Getting url http://ova.arg.tech/db/23948...
#
# Done
# ----
# Checking for argmap at nodeset 23949 (node 18/49)
#  Getting url http://ova.arg.tech/db/23949...
#
# Done
# ----
# Checking for argmap at nodeset 23950 (node 19/49)
#  Getting url http://ova.arg.tech/db/23950...
#
# Done
# ----
# Checking for argmap at nodeset 23951 (node 20/49)
#  Getting url http://ova.arg.tech/db/23951...
#
# Done
# ----
# Checking for argmap at nodeset 23953 (node 21/49)
#  Getting url http://ova.arg.tech/db/23953...
#
# Done
# ----
# Checking for argmap at nodeset 23954 (node 22/49)
#  Getting url http://ova.arg.tech/db/23954...
#
# Done
# ----
# Checking for argmap at nodeset 23955 (node 23/49)
#  Getting url http://ova.arg.tech/db/23955...
#
# Done
# ----
# Checking for argmap at nodeset 23956 (node 24/49)
#  Getting url http://ova.arg.tech/db/23956...
#
# Done
# ----
# Checking for argmap at nodeset 23958 (node 25/49)
#  Getting url http://ova.arg.tech/db/23958...
#
# Done
# ----
# Checking for argmap at nodeset 23959 (node 26/49)
#  Getting url http://ova.arg.tech/db/23959...
#
# Done
# ----
# Checking for argmap at nodeset 23960 (node 27/49)
#  Getting url http://ova.arg.tech/db/23960...
#
# Done
# ----
# Checking for argmap at nodeset 23961 (node 28/49)
#  Getting url http://ova.arg.tech/db/23961...
#
# Done
# ----
# Checking for argmap at nodeset 23962 (node 29/49)
#  Getting url http://ova.arg.tech/db/23962...
#
json
# already OVA3
# ./qt30_error_finding/ova3_episode_maps/4june2020/18292.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18284.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18318.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18271.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18267.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18288.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18322.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18283.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18295.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18313.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18299.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18309.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18308.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18298.json
# ./qt30_error_finding/ova3_episode_maps/4june2020/18282.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17932.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17945.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/18673.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17968.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17929.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17952.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17944.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17964.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17933.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17925.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17972.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/18994.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/18989.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17938.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17918.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/18985.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17959.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17975.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17934.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17963.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17962.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17923.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17974.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17958.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/25429.json
# already OVA3
# ./qt30_error_finding/ova3_episode_maps/28may2020/17919.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17957.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17941.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17961.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17921.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17937.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17960.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17940.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/26067.json
# already OVA3
# ./qt30_error_finding/ova3_episode_maps/28may2020/17930.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17971.json
# ./qt30_error_finding/ova3_episode_maps/28may2020/17966.json

# %% [markdown]
# Functions for consistent/repeat errors

# %%
def qt30_text_namefix(text_to_fix, filename, verbose=False):
    for fix_it in [('Luke McCroy Jones', 'Luke McCroy-Jones'), ('Kate Frobes', 'Kate Forbes'),
                   ('Chris Philip', 'Chris Philp'), ('Goerge Mpanga', 'George Mpanga'), ('George MPanga', 'George Mpanga')]:
        if fix_it[0] in text_to_fix:
            if verbose:
                print(f"{os.path.basename(filename)}: {fix_it[0]} error")
            # text_to_fix = text_to_fix.replace(fix_it[0], fix_it[1])
            text_to_fix = re.sub(fix_it[0], fix_it[1], text_to_fix)
    return text_to_fix


# For consistency, replace instances of 'Andrew RT Davies' in the transcript in L-nodes with 'Andrew Davies'
def andy_fix(xaif, verbose=False):
    in_l = False
    in_txt = False
    
    corrected_nodes = []
    # Convert L-node speakers
    for l in xaif['AIF']['nodes']:
        if l['type'] == 'L':
            if re.search('Andrew RT Davies[\s]*:', l['text']):
                l['text'] = re.sub('Andrew RT Davies[\s]*:', 'Andrew Davies :', l['text'])
                in_l = True
                if verbose:
                    print(f"Node {l['nodeID']}: {l['text']}")
        corrected_nodes.append(l)
    xaif['AIF']['nodes'] = corrected_nodes
    
    # Convert transcript attributions
    if 'Andrew RT Davies' in xaif['text']:
        if verbose:
            print('\tAndrew RT Davies found in text')
        xaif['text'] = re.sub('Andrew RT Davies', 'Andrew Davies', xaif['text'])
        # xaif['text'] = re.sub(r"(^|(?<=[\.\"?\'!’…;>]))(Andrew RT Davies)(?=(<.*>)*\[.*?)", '\\1Andrew Davies\\3', xaif['text'])
    
    if verbose:
        if in_l:
            print('\tAndrew RT Davies found in L-node(s)')
    
    return xaif

# One case for fixing names to be consistent across text and L-nodes : gave up on this immediately
def misc_name_fixes(xaif):
    for l in [n for n in xaif['AIF']['nodes'] if n['type'] == 'L']:
        l['text'] = re.sub('Craig Davis :', 'Craig Unknown :', l['text'])
    return xaif


# Make use of 'Unknown' consistent across nodes and transcript
# Assumes speaker attribution is identifiable by a space after speaker name.
def audience_unk(xaif, verbose=False):
    # Check L-nodes
    corrected_nodes = []
    nodes_with_unk = []
    unk_spkrs = []
    # Make sure capitalisation of L-node speakers is consistent
    for n in xaif['AIF']['nodes']:
        if n['type'] != 'L':
            corrected_nodes.append(n)
        else:
            # Check for start to skip annotator nodes
            if re.findall("^[\w*\d*]+ [Uu]nknown[\s]*:", n['text']):
                n['text'] = re.sub('[Uu]nknown[\s]*:', 'Unknown :', n['text'])
                corrected_nodes.append(n)
                nodes_with_unk.append(n)

                splits = n['text'].split(':')
                if len(splits) < 2:
                    print(f"L-node with no recognisable speaker:\t{n['nodeID']}")
                else:
                    spkr = splits[0].strip()
                if spkr not in unk_spkrs:
                    unk_spkrs.append(spkr)
            else:
                corrected_nodes.append(n)
    if verbose:
        if len(unk_spkrs) > 0:
            print(unk_spkrs)
            print(xaif['text'])
    # Handle text
    for spkr in unk_spkrs:
        first_name = spkr.split()[0]
        # Allow for either immediate timestamp or immediate tag.
        xaif['text'] = re.sub(f"{first_name}[\s]*\[", f"{first_name} Unknown[", xaif['text'])
        xaif['text'] = re.sub(f"{first_name}[\s]*\<", f"{first_name} Unknown<", xaif['text'])

    xaif['AIF']['nodes'] = corrected_nodes
    return xaif

# Some audience names were partially converted to codes, but only in L-nodes
# If this has been done, update their name in the transcript
def audience_name2code(xaif, verbose=False):
    codename_nodes = []

    # Collect all L-nodes that have an AudienceMember speaker and are linked to the text
    l_nodes = [n for n in xaif['AIF']['nodes'] if n['type'] == 'L']
    if verbose:
        print(f"{len(l_nodes)} L-nodes to check")
    
    for l in l_nodes:
        codename = re.findall("^AudienceMember \d\d\d\d\d\d\d\dQT\d\d", l['text'])
        if codename:
            if verbose:
                print(f"\tFound {codename[0]} in node {l['nodeID']}, ", end='')
                # print(f"\t\t" + l['text'])
            direct_loc = re.findall(f"node{l['nodeID']}", xaif['text'])
            if direct_loc:
                if verbose:
                    print(f"node {l['nodeID']} found in text")
                codename_nodes.append({'name': codename[0], 'nodeID': l['nodeID']})
                # if verbose:
                    # print(codename_nodes[-1])
            else:
                if verbose:
                    print(f"node {l['nodeID']} not found in text")
            if verbose:
                print(f"\t{l['text']}")
                print()

    if verbose and len(codename_nodes) > 0:
        print("Now checking for each codname entry")
    # Check how the speaker is named in the transcript: if stripped version isn't codename, replace
    for n in codename_nodes:
        if verbose:
            print("Checking for node ", n['nodeID'])
        match_iter = re.finditer(f"(^|(?<=[\.\"?\'!’…;>]))([\'\s\w+]+)?(?=(<.*>)*\[.*?id=\"node{n['nodeID']})", xaif['text'])
        match_list = [m for m in match_iter]
        if verbose:
            print(f"\nList of matches for {n['nodeID']}")
            print(match_list)
        if len(match_list) == 0:
            print(f"Failed to match name {n['name']} for node {n['nodeID']}")
            continue
        else:
            # Orig picking last won't work if there's a linebreak between the name and stamp
            target = match_list[-1]
            # Change: work backwards skipping blanks until first non-blank
            for t in reversed(match_list):
                if t.group().strip() != '':
                    target = t
                    break
            if verbose:
                print(f"Matching ", target)
            if target.group().strip() != n['name'].strip():
                if verbose:
                    print('MISMATCH! Going to correct text')
                    print(f"{target.group().strip()} != {n['name'].strip()}")
            # print(xaif['text'][:target.span()[0]] + n['name'] + xaif['text'][target.span()[1]:])
                xaif['text'] = xaif['text'][:target.span()[0]] + n['name'] + xaif['text'][target.span()[1]:]
            else:
                print(f"Already correct for node {n['nodeID']}")
    return xaif

# %% [markdown]
# Sample of running one in-place fixer:

# %%
for ep in ep_names:
    print(f'\n*** {ep} ***')
    ep_files = glob(f'./qt30_error_finding/ova3_episode_maps/{ep}/*.json')
    print(ep_files)
    for mapfile in ep_files:
        print('\t', mapfile)

        with open(mapfile, 'r') as f:
            argmap = json.loads(f.read())
        
        for n in argmap['AIF']['nodes']:
            n['text'] = qt30_text_namefix(n['text'], mapfile)
        argmap['text'] = qt30_text_namefix(argmap['text'], mapfile)
        continue # don't actually run this here
        with open(mapfile, 'w') as f:
            json.dump(argmap, f, indent=4)
# Out:
# *** 11november2021 ***
# ['./qt30_error_finding/ova3_episode_maps/11november2021/23515.json', './qt30_error_finding/ova3_episode_maps/11november2021/23503.json', './qt30_error_finding/ova3_episode_maps/11november2021/23485.json', './qt30_error_finding/ova3_episode_maps/11november2021/23688.json', './qt30_error_finding/ova3_episode_maps/11november2021/23488.json', './qt30_error_finding/ova3_episode_maps/11november2021/23484.json', './qt30_error_finding/ova3_episode_maps/11november2021/23555.json', './qt30_error_finding/ova3_episode_maps/11november2021/23502.json', './qt30_error_finding/ova3_episode_maps/11november2021/23514.json', './qt30_error_finding/ova3_episode_maps/11november2021/23509.json', './qt30_error_finding/ova3_episode_maps/11november2021/23460.json', './qt30_error_finding/ova3_episode_maps/11november2021/23476.json', './qt30_error_finding/ova3_episode_maps/11november2021/23513.json', './qt30_error_finding/ova3_episode_maps/11november2021/23505.json', './qt30_error_finding/ova3_episode_maps/11november2021/25691.json', './qt30_error_finding/ova3_episode_maps/11november2021/23483.json', './qt30_error_finding/ova3_episode_maps/11november2021/23495.json', './qt30_error_finding/ova3_episode_maps/11november2021/23494.json', './qt30_error_finding/ova3_episode_maps/11november2021/25690.json', './qt30_error_finding/ova3_episode_maps/11november2021/23504.json', './qt30_error_finding/ova3_episode_maps/11november2021/24042.json', './qt30_error_finding/ova3_episode_maps/11november2021/23512.json', './qt30_error_finding/ova3_episode_maps/11november2021/25409.json', './qt30_error_finding/ova3_episode_maps/11november2021/23498.json', './qt30_error_finding/ova3_episode_maps/11november2021/23508.json', './qt30_error_finding/ova3_episode_maps/11november2021/23497.json', './qt30_error_finding/ova3_episode_maps/11november2021/23478.json', './qt30_error_finding/ova3_episode_maps/11november2021/23481.json', './qt30_error_finding/ova3_episode_maps/11november2021/23507.json', './qt30_error_finding/ova3_episode_maps/11november2021/23511.json', './qt30_error_finding/ova3_episode_maps/11november2021/23510.json', './qt30_error_finding/ova3_episode_maps/11november2021/23506.json', './qt30_error_finding/ova3_episode_maps/11november2021/23480.json', './qt30_error_finding/ova3_episode_maps/11november2021/23496.json', './qt30_error_finding/ova3_episode_maps/11november2021/23479.json', './qt30_error_finding/ova3_episode_maps/11november2021/23475.json', './qt30_error_finding/ova3_episode_maps/11november2021/23491.json', './qt30_error_finding/ova3_episode_maps/11november2021/23487.json', './qt30_error_finding/ova3_episode_maps/11november2021/23517.json', './qt30_error_finding/ova3_episode_maps/11november2021/23473.json', './qt30_error_finding/ova3_episode_maps/11november2021/23500.json']
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23515.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23503.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23485.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23688.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23488.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23484.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/23555.json
# 	 ./qt30_error_finding/ova3_episode_maps/11november2021/
/28may2020/17925.json', './qt30_error_finding/ova3_episode_maps/28may2020/17972.json', './qt30_error_finding/ova3_episode_maps/28may2020/18994.json', './qt30_error_finding/ova3_episode_maps/28may2020/18989.json', './qt30_error_finding/ova3_episode_maps/28may2020/17938.json', './qt30_error_finding/ova3_episode_maps/28may2020/17918.json', './qt30_error_finding/ova3_episode_maps/28may2020/18985.json', './qt30_error_finding/ova3_episode_maps/28may2020/17959.json', './qt30_error_finding/ova3_episode_maps/28may2020/17975.json', './qt30_error_finding/ova3_episode_maps/28may2020/17934.json', './qt30_error_finding/ova3_episode_maps/28may2020/17963.json', './qt30_error_finding/ova3_episode_maps/28may2020/17962.json', './qt30_error_finding/ova3_episode_maps/28may2020/17923.json', './qt30_error_finding/ova3_episode_maps/28may2020/17974.json', './qt30_error_finding/ova3_episode_maps/28may2020/17958.json', './qt30_error_finding/ova3_episode_maps/28may2020/25429.json', './qt30_error_finding/ova3_episode_maps/28may2020/17919.json', './qt30_error_finding/ova3_episode_maps/28may2020/17957.json', './qt30_error_finding/ova3_episode_maps/28may2020/17941.json', './qt30_error_finding/ova3_episode_maps/28may2020/17961.json', './qt30_error_finding/ova3_episode_maps/28may2020/17921.json', './qt30_error_finding/ova3_episode_maps/28may2020/17937.json', './qt30_error_finding/ova3_episode_maps/28may2020/17960.json', './qt30_error_finding/ova3_episode_maps/28may2020/17940.json', './qt30_error_finding/ova3_episode_maps/28may2020/26067.json', './qt30_error_finding/ova3_episode_maps/28may2020/17930.json', './qt30_error_finding/ova3_episode_maps/28may2020/17971.json', './qt30_error_finding/ova3_episode_maps/28may2020/17966.json']
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17932.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17945.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/18673.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17968.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17929.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17952.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17944.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17964.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17933.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17925.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17972.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/18994.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/18989.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17938.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17918.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/18985.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17959.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17975.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17934.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17963.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17962.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17923.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17974.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17958.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/25429.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17919.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17957.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17941.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17961.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17921.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17937.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17960.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17940.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/26067.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17930.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17971.json
# 	 ./qt30_error_finding/ova3_episode_maps/28may2020/17966.json

# %% [markdown]
# Trial and error: running analytics on each file and adding a hacky fix to problems as identified.

# %%
# 1) Systematic fixes
for i, ep in enumerate(ep_names):
    print(f"\n=== Episode {ep} ({i+1}/30)===")
    # maps  = glob(f'./qt30_error_finding/ova3_mini_name_edits/{ep}/*.json')
    maps  = glob(f'./qt30_error_finding/ova3_episode_maps/{ep}/*.json')
    if not os.path.exists(f'./qt30_error_finding/ova3_systemic_fix/{ep}'):
        os.makedirs(f'./qt30_error_finding/ova3_systemic_fix/{ep}')

    for mapfile in maps:
        # print(os.path.basename(mapfile))
        print(f"Opening {mapfile}")
        with open(mapfile) as f:
            xaif = json.loads(f.read())
        
        # xaif = xaif_toolbox.remove_all_meta(xaif)
        xaif = andy_fix(xaif)
        xaif = misc_name_fixes(xaif)
        xaif = audience_unk(xaif)
        xaif = audience_name2code(xaif, verbose=True)

        for n in xaif['AIF']['nodes']:
            n['text'] = qt30_text_namefix(n['text'], mapfile)
        xaif['text'] = qt30_text_namefix(xaif['text'], mapfile)

        with open(f'./qt30_error_finding/ova3_systemic_fix/{ep}/{os.path.basename(mapfile)}', 'w') as f:
            json.dump(xaif, f, indent=4)
# Out:
# === Episode 11november2021 (1/30)===
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23515.json
# 52 L-nodes to check
# 	Found AudienceMember 20211111QT18 in node 140_23515, node 140_23515 found in text
# 	AudienceMember 20211111QT18 : A lot of this comes to the cost of the person
#
# 	Found AudienceMember 20211111QT18 in node 147_23515, node 147_23515 found in text
# 	AudienceMember 20211111QT18 : Being in Eastleigh we're close to an airport and a station which have fantastic ability to get anywhere
#
# 	Found AudienceMember 20211111QT18 in node 155_23515, node 155_23515 found in text
# 	AudienceMember 20211111QT18 : I wanted to go to Edinburgh
#
# 	Found AudienceMember 20211111QT18 in node 166_23515, node 166_23515 found in text
# 	AudienceMember 20211111QT18 : I can't get there for £30 on a flight
#
# 	Found AudienceMember 20211111QT18 in node 188_23515, node 188_23515 found in text
# 	AudienceMember 20211111QT18 : I want to drive to be green
#
# 	Found AudienceMember 20211111QT18 in node 195_23515, node 195_23515 found in text
# 	AudienceMember 20211111QT18 : that choice is taken away from me
#
# 	Found AudienceMember 20211111QT18 in node 206_23515, node 206_23515 found in text
# 	AudienceMember 20211111QT18 : The same is I would love to have an electric car
#
# 	Found AudienceMember 20211111QT18 in node 213_23515, node 213_23515 found in text
# 	AudienceMember 20211111QT18 : I live in a terraced house
#
# 	Found AudienceMember 20211111QT18 in node 244_23515, node 244_23515 found in text
# 	AudienceMember 20211111QT18 : If I used the train
#
# 	Found AudienceMember 20211111QT18 in node 255_23515, node 255_23515 found in text
# 	AudienceMember 20211111QT18 : it would be well over £100
#
# Now checking for each codname entry
# Checking for node  140_23515
#
# List of matches for 140_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 140_23515
# Checking for node  147_23515
#
# List of matches for 147_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 147_23515
# Checking for node  155_23515
#
# List of matches for 155_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 155_23515
# Checking for node  166_23515
#
# List of matches for 166_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 166_23515
# Checking for node  188_23515
#
# List of matches for 188_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 188_23515
# Checking for node  195_23515
#
# List of matches for 195_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 195_23515
# Checking for node  206_23515
#
# List of matches for 206_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 206_23515
# Checking for node  213_23515
#
# List of matches for 213_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 213_23515
# Checking for node  244_23515
#
# List of matches for 244_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 244_23515
# Checking for node  255_23515
#
# List of matches for 255_23515
# [<regex.Match object; span=(0, 16), match='Emily Thornberry'>, <regex.Match object; span=(1507, 1518), match='Fiona Bruce'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT18'>
# Already correct for node 255_23515
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23503.json
# 30 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23485.json
# 45 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23688.json
# 30 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23488.json
# 42 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23484.json
# 31 L-nodes to check
# 	Found AudienceMember 20211111QT10 in node 86_23484, node 86_23484 not found in text
# 	AudienceMember 20211111QT10 : given that Russia, India and China didn't turn up, how successful are the breakthrough pledges of COP-26, a glimmer of hope or blah blah blah
#
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23555.json
# 17 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23502.json
# 26 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23514.json
# 39 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23509.json
# 40 L-nodes to check
# 	Found AudienceMember 20211111QT17 in node 66_23509, node 66_23509 found in text
# 	AudienceMember 20211111QT17 :  How can people afford to be able to change to heat pump systems and electric cars, given the cost of these things
#
# Now checking for each codname entry
# Checking for node  66_23509
#
# List of matches for 66_23509
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(847, 858), match='Fiona Bruce'>, <regex.Match object; span=(955, 982), match='AudienceMember 20211111QT17'>]
# Matching  <regex.Match object; span=(955, 982), match='AudienceMember 20211111QT17'>
# Already correct for node 66_23509
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23460.json
# 15 L-nodes to check
# 	Found AudienceMember 20211111QT01 in node 1_23460, node 1_23460 found in text
# 	AudienceMember 20211111QT01 : Has Tory sleaze returned
#
# Now checking for each codname entry
# Checking for node  1_23460
#
# List of matches for 1_23460
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(95, 122), match='AudienceMember 20211111QT01'>]
# Matching  <regex.Match object; span=(95, 122), match='AudienceMember 20211111QT01'>
# Already correct for node 1_23460
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23476.json
# 26 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23513.json
# 43 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23505.json
# 44 L-nodes to check
# 	Found AudienceMember 20211111QT11 in node 49_23505, node 49_23505 found in text
# 	AudienceMember 20211111QT11 : The cost to the consumer, the general public
#
# 	Found AudienceMember 20211111QT11 in node 54_23505, node 54_23505 found in text
# 	AudienceMember 20211111QT11 : what about the actual politicians that are attending this conference
#
# 	Found AudienceMember 20211111QT11 in node 66_23505, node 66_23505 found in text
# 	AudienceMember 20211111QT11 : They're flying from all over the world
#
# 	Found AudienceMember 20211111QT11 in node 77_23505, node 77_23505 found in text
# 	AudienceMember 20211111QT11 : The American President landed on Air Force One
#
# 	Found AudienceMember 20211111QT11 in node 82_23505, node 82_23505 found in text
# 	AudienceMember 20211111QT11 : He had many limousines to take him to the actual conference
#
# 	Found AudienceMember 20211111QT11 in node 96_23505, node 96_23505 found in text
# 	AudienceMember 20211111QT11 : How is that helping climate change
#
# 	Found AudienceMember 20211111QT12 in node 109_23505, node 109_23505 found in text
# 	AudienceMember 20211111QT12 : It doesn't
#
# 	Found AudienceMember 20211111QT12 in node 120_23505, node 120_23505 found in text
# 	AudienceMember 20211111QT12 : it's disgusting
#
# 	Found AudienceMember 20211111QT12 in node 125_23505, node 125_23505 found in text
# 	AudienceMember 20211111QT12 : the conference should have been as virtual as possible
#
# 	Found AudienceMember 20211111QT12 in node 138_23505, node 138_23505 found in text
# 	AudienceMember 20211111QT12 : This is my point
#
# 	Found AudienceMember 20211111QT12 in node 143_23505, node 143_23505 found in text
# 	AudienceMember 20211111QT12 : Politicians are going to ask us to make significant sacrifices in the next few years
#
# 	Found AudienceMember 20211111QT12 in node 148_23505, node 148_23505 found in text
# 	AudienceMember 20211111QT12 : they are still flying to a climate conference
#
# 	Found AudienceMember 20211111QT12 in node 153_23505, node 153_23505 found in text
# 	AudienceMember 20211111QT12 : in the middle of a pandemic
#
# 	Found AudienceMember 20211111QT12 in node 158_23505, node 158_23505 found in text
# 	AudienceMember 20211111QT12 : looks absolutely appalling
#
# 	Found AudienceMember 20211111QT12 in node 194_23505, node 194_23505 found in text
# 	AudienceMember 20211111QT12 : fish gotta swim and the rich got to fly
#
# 	Found AudienceMember 20211111QT12 in node 199_23505, node 199_23505 found in text
# 	AudienceMember 20211111QT12 : they are trying to persuade us, ordinary people, to adjust our lifestyles to meet their ambitions
#
# 	Found AudienceMember 20211111QT12 in node 204_23505, node 204_23505 found in text
# 	AudienceMember 20211111QT12 : it is about time they started to do it as well
#
# Now checking for each codname entry
# Checking for node  49_23505
#
# List of matches for 49_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 49_23505
# Checking for node  54_23505
#
# List of matches for 54_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 54_23505
# Checking for node  66_23505
#
# List of matches for 66_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 66_23505
# Checking for node  77_23505
#
# List of matches for 77_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 77_23505
# Checking for node  82_23505
#
# List of matches for 82_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 82_23505
# Checking for node  96_23505
#
# List of matches for 96_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>]
# Matching  <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>
# Already correct for node 96_23505
# Checking for node  109_23505
#
# List of matches for 109_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 109_23505
# Checking for node  120_23505
#
# List of matches for 120_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 120_23505
# Checking for node  125_23505
#
# List of matches for 125_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 125_23505
# Checking for node  138_23505
#
# List of matches for 138_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 138_23505
# Checking for node  143_23505
#
# List of matches for 143_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 143_23505
# Checking for node  148_23505
#
# List of matches for 148_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 148_23505
# Checking for node  153_23505
#
# List of matches for 153_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 153_23505
# Checking for node  158_23505
#
# List of matches for 158_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 158_23505
# Checking for node  194_23505
#
# List of matches for 194_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 194_23505
# Checking for node  199_23505
#
# List of matches for 199_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 199_23505
# Checking for node  204_23505
#
# List of matches for 204_23505
# [<regex.Match object; span=(0, 11), match='Tim Stanley'>, <regex.Match object; span=(828, 839), match='Fiona Bruce'>, <regex.Match object; span=(889, 916), match='AudienceMember 20211111QT11'>, <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>]
# Matching  <regex.Match object; span=(1576, 1603), match='AudienceMember 20211111QT12'>
# Already correct for node 204_23505
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/25691.json
# 42 L-nodes to check
# 	Found AudienceMember 20211111QT22 in node 130_165753052390060522, node 130_165753052390060522 found in text
# 	AudienceMember 20211111QT22 : Can a racist term ever be defined as banter
#
# Now checking for each codname entry
# Checking for node  130_165753052390060522
#
# List of matches for 130_165753052390060522
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(765, 776), match='Fiona Bruce'>, <regex.Match object; span=(1133, 1160), match='AudienceMember 20211111QT22'>]
# Matching  <regex.Match object; span=(1133, 1160), match='AudienceMember 20211111QT22'>
# Already correct for node 130_165753052390060522
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23483.json
# 30 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23495.json
# 34 L-nodes to check
# 	Found AudienceMember 20211111QT10 in node 1_23495, node 1_23495 found in text
# 	AudienceMember 20211111QT10 : Without the likes of Russia, India and China on board, are this week's COP-26 breakthrough pledges such as the reduction of methane emissions a glimmer of hope or more blah blah blah
#
# Now checking for each codname entry
# Checking for node  1_23495
#
# List of matches for 1_23495
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(73, 100), match='AudienceMember 20211111QT10'>]
# Matching  <regex.Match object; span=(73, 100), match='AudienceMember 20211111QT10'>
# Already correct for node 1_23495
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23494.json
# 34 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/25690.json
# 34 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23504.json
# 34 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/24042.json
# 42 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23512.json
# 43 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/25409.json
# 29 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23498.json
# 32 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23508.json
# 40 L-nodes to check
# 	Found AudienceMember 20211111QT19 in node 1_23508, node 1_23508 found in text
# 	AudienceMember 20211111QT19 : A friend of mine has an electric car and suffers very regularly with juice anxiety
#
# 	Found AudienceMember 20211111QT19 in node 15_23508, node 15_23508 found in text
# 	AudienceMember 20211111QT19 : Juice anxiety. It's a thing
#
# 	Found AudienceMember 20211111QT19 in node 40_23508, node 40_23508 found in text
# 	AudienceMember 20211111QT19 : He drives around and I have had a late night call saying "Can I come to your house and charge my car on the plug because I may not be able to get back home"
#
# 	Found AudienceMember 20211111QT19 in node 48_23508, node 48_23508 not found in text
# 	AudienceMember 20211111QT19's  Friend : Can I come to your house and charge my car on the plug because I may not be able to get back home"
#
# 	Found AudienceMember 20211111QT19 in node 57_23508, node 57_23508 found in text
# 	AudienceMember 20211111QT19 : The charging units are out of order
#
# 	Found AudienceMember 20211111QT19 in node 64_23508, node 64_23508 found in text
# 	AudienceMember 20211111QT19 : There might be somebody in the unit charging their car, having a coffee, and he is waiting
#
# 	Found AudienceMember 20211111QT19 in node 80_23508, node 80_23508 found in text
# 	AudienceMember 20211111QT19 : I don't think in this area there is enough chargers
#
# 	Found AudienceMember 20211111QT19 in node 100_23508, node 100_23508 found in text
# 	AudienceMember 20211111QT19 : I would love an electric car
#
# 	Found AudienceMember 20211111QT19 in node 107_23508, node 107_23508 found in text
# 	AudienceMember 20211111QT19 : I don't want to suffer right now with juice anxiety
#
# Now checking for each codname entry
# Checking for node  1_23508
#
# List of matches for 1_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>
# Already correct for node 1_23508
# Checking for node  15_23508
#
# List of matches for 15_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT20'>]
# Matching  <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT20'>
# MISMATCH! Going to correct text
# AudienceMember 20211111QT20 != AudienceMember 20211111QT19
# Checking for node  40_23508
#
# List of matches for 40_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT21'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT21'>
# MISMATCH! Going to correct text
# AudienceMember 20211111QT21 != AudienceMember 20211111QT19
# Checking for node  57_23508
#
# List of matches for 57_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>
# Already correct for node 57_23508
# Checking for node  64_23508
#
# List of matches for 64_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>
# Already correct for node 64_23508
# Checking for node  80_23508
#
# List of matches for 80_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>
# Already correct for node 80_23508
# Checking for node  100_23508
#
# List of matches for 100_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>
# Already correct for node 100_23508
# Checking for node  107_23508
#
# List of matches for 107_23508
# [<regex.Match object; span=(0, 27), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(170, 181), match='Fiona Bruce'>, <regex.Match object; span=(255, 282), match='AudienceMember 20211111QT19'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>]
# Matching  <regex.Match object; span=(489, 516), match='AudienceMember 20211111QT19'>
# Already correct for node 107_23508
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23497.json
# 41 L-nodes to check
# 	Found AudienceMember 20211111QT14 in node 1_23497, node 1_23497 found in text
# 	AudienceMember 20211111QT14 : Personal responsibility is important
#
# 	Found AudienceMember 20211111QT14 in node 6_23497, node 6_23497 found in text
# 	AudienceMember 20211111QT14 : Where's the emphasis being placed on corporate responsibility who create the most emissions
#
# 	Found AudienceMember 20211111QT16 in node 35_23497, node 35_23497 found in text
# 	AudienceMember 20211111QT16 : they're not backed by anything
#
# 	Found AudienceMember 20211111QT16 in node 40_23497, node 40_23497 found in text
# 	AudienceMember 20211111QT16 : they are just weak promises
#
# 	Found AudienceMember 20211111QT16 in node 51_23497, node 51_23497 found in text
# 	AudienceMember 20211111QT16 : One of the issues I have is the politicians are making these pledges
#
# 	Found AudienceMember 20211111QT16 in node 64_23497, node 64_23497 found in text
# 	AudienceMember 20211111QT16 : The problem we have is lot of the leaders are using this as a photo opportunity
#
# 	Found AudienceMember 20211111QT16 in node 69_23497, node 69_23497 found in text
# 	AudienceMember 20211111QT16 : The chancellor brings forward a green budget box
#
# 	Found AudienceMember 20211111QT16 in node 74_23497, node 74_23497 found in text
# 	AudienceMember 20211111QT16 : A few weeks ago in his budget box he was cutting the tax that people pay for domestic flight
#
# 	Found AudienceMember 20211111QT16 in node 79_23497, node 79_23497 found in text
# 	AudienceMember 20211111QT16 : which was a different colour
#
# 	Found AudienceMember 20211111QT16 in node 84_23497, node 84_23497 found in text
# 	AudienceMember 20211111QT16 : Domestic flights is the worst possible way that you can move around
#
# 	Found AudienceMember 20211111QT16 in node 94_23497, node 94_23497 found in text
# 	AudienceMember 20211111QT16 : It doesn't join up with the pledges they are making now
#
# 	Found AudienceMember 20211111QT16 in node 175_23497, node 175_23497 found in text
# 	AudienceMember 20211111QT16 : now is the time where we are starting to outline what action is going to be taken
#
# Now checking for each codname entry
# Checking for node  1_23497
#
# List of matches for 1_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>]
# Matching  <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>
# Already correct for node 1_23497
# Checking for node  6_23497
#
# List of matches for 6_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>]
# Matching  <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>
# Already correct for node 6_23497
# Checking for node  35_23497
#
# List of matches for 35_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 35_23497
# Checking for node  40_23497
#
# List of matches for 40_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 40_23497
# Checking for node  51_23497
#
# List of matches for 51_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 51_23497
# Checking for node  64_23497
#
# List of matches for 64_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 64_23497
# Checking for node  69_23497
#
# List of matches for 69_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 69_23497
# Checking for node  74_23497
#
# List of matches for 74_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 74_23497
# Checking for node  79_23497
#
# List of matches for 79_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 79_23497
# Checking for node  84_23497
#
# List of matches for 84_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 84_23497
# Checking for node  94_23497
#
# List of matches for 94_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>]
# Matching  <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>
# Already correct for node 94_23497
# Checking for node  175_23497
#
# List of matches for 175_23497
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(78, 105), match='AudienceMember 20211111QT14'>, <regex.Match object; span=(371, 382), match='Fiona Bruce'>, <regex.Match object; span=(475, 502), match='AudienceMember 20211111QT15'>, <regex.Match object; span=(658, 685), match='AudienceMember 20211111QT16'>, <regex.Match object; span=(1692, 1703), match='Paul Scully'>]
# Matching  <regex.Match object; span=(1692, 1703), match='Paul Scully'>
# MISMATCH! Going to correct text
# Paul Scully != AudienceMember 20211111QT16
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23478.json
# 30 L-nodes to check
# 	Found AudienceMember 20211111QT06 in node 13_23478, node 13_23478 found in text
# 	AudienceMember 20211111QT06 : the MPs should only be dealing with their constituency issues
#
# 	Found AudienceMember 20211111QT06 in node 18_23478, node 18_23478 found in text
# 	AudienceMember 20211111QT06 : not taking on multiple roles
#
# 	Found AudienceMember 20211111QT06 in node 23_23478, node 23_23478 found in text
# 	AudienceMember 20211111QT06 : By taking on multiple roles it is saying the issues within their constituency is a part-time role
#
# 	Found AudienceMember 20211111QT06 in node 28_23478, node 28_23478 found in text
# 	AudienceMember 20211111QT06 : So I therefore have time to take payment from other companies
#
# 	Found AudienceMember 20211111QT06 in node 33_23478, node 33_23478 found in text
# 	AudienceMember 20211111QT06 : When you are elected into this particular role for your constituency, you act for them, them alone and nobody else
#
# Now checking for each codname entry
# Checking for node  13_23478
#
# List of matches for 13_23478
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>]
# Matching  <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>
# Already correct for node 13_23478
# Checking for node  18_23478
#
# List of matches for 18_23478
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>]
# Matching  <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>
# Already correct for node 18_23478
# Checking for node  23_23478
#
# List of matches for 23_23478
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>]
# Matching  <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>
# Already correct for node 23_23478
# Checking for node  28_23478
#
# List of matches for 28_23478
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>]
# Matching  <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>
# Already correct for node 28_23478
# Checking for node  33_23478
#
# List of matches for 33_23478
# [<regex.Match object; span=(0, 11), match='Fiona Bruce'>, <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>]
# Matching  <regex.Match object; span=(152, 179), match='AudienceMember 20211111QT06'>
# Already correct for node 33_23478
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23481.json
# 34 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23507.json
# 37 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/11november2021/23511.json
# 55 L-nodes to check
# 	Found AudienceMember 20211111QT07 in node 137_23511, node 137_23511 found in text
# 	AudienceMember 20211111QT07 : Was it because of Mr Paterson
#
# 	Found AudienceMember 20211111QT07 in node 144_23511, node 144_23511 found in text
# 	AudienceMember 20211111QT07 : is it because the process needs review
#
# 	Found AudienceMember 20211111QT07 in node 168_23511, node 168_23511 found in text
# 	AudienceMember 20211111QT07 : Either way, as the gentlemen just said, once you committed something under one set of rules, you shouldn't suddenly change them
#
# 	Found AudienceMember 20211111QT07 in node 179_23511, node 179_23511 found in text
# 	AudienceMember 20211111QT07 : Change the rules, by all means
#
# 	Found AudienceMember 20211111QT07 in node 187_23511, node 187_23511 found in text
# 	AudienceMember 20211111QT07 : do that because you need to change them
#
# 	Found AudienceMember 20211111QT07 in node 192_23511, node 192_23511 found in text
# 	AudienceMember 20211111QT07 : not because one of your mates has got a problem
#
# 	Found AudienceMember 20211111QT07 in node 297_23511, node 297_23511 found in text
# 	AudienceMember 20211111QT07 : when the government decided this process needed review
#
# Now checking for each codname entry
# Checking for node  137_23511
#
# List of matches for 137_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 137_23511
# Checking for node  144_23511
#
# List of matches for 144_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 144_23511
# Checking for node  168_23511
#
# List of matches for 168_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 168_23511
# Checking for node  179_23511
#
# List of matches for 179_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 179_23511
# Checking for node  187_23511
#
# List of matches for 187_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 187_23511
# Checking for node  192_23511
#
# List of matches for 192_23511
# [<regex.Match object; span=(0, 11), match='Paul Polman'>, <regex.Match object; span=(15, 15), match=''>, <regex.Match object; span=(71, 222), match='for individual companies to pay for very specific tasks to be done is something that I think might have been accepted in the public eye a few years ago'>, <regex.Match object; span=(229, 234), match=' but '>, <regex.Match object; span=(277, 339), match='should be looked at now in the world that we live in currently'>, <regex.Match object; span=(347, 348), match=' '>, <regex.Match object; span=(458, 558), match="re as much part of this problem that we're discussing as the people here that are being talked about">, <regex.Match object; span=(566, 567), match=' '>, <regex.Match object; span=(662, 671), match=' I think '>, <regex.Match object; span=(716, 748), match='in this case the horses were out'>, <regex.Match object; span=(806, 824), match="that's regrettable">, <regex.Match object; span=(832, 833), match=' '>, <regex.Match object; span=(877, 941), match='It would be good to provide laws that were broader to cover this'>, <regex.Match object; span=(949, 949), match=''>, <regex.Match object; span=(953, 953), match=''>, <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>, <regex.Match object; span=(988, 988), match=''>]
# Matching  <regex.Match object; span=(957, 984), match='AudienceMember 20211111QT07'>
# Already correct for node 192_23511
# Checking for node  297_23511
#
# List of matches for 297_23511
# ...
# 25 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18782.json
# 28 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18794.json
# 38 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18813.json
# 27 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18809.json
# 39 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18761.json
# 23 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18798.json
# 33 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18799.json
# 44 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18760.json
# 22 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18808.json
# 38 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18977.json
# 32 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/25566.json
# 36 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18812.json
# 43 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18795.json
# 24 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18804.json
# 33 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18756.json
# 20 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/25561.json
# 24 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18767.json
# 23 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18788.json
# 31 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18751.json
# 23 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/18803.json
# 29 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/25557.json
# 47 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/30july2020/
L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/28may2020/17940.json
# 56 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/28may2020/26067.json
# 36 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/28may2020/17930.json
# 41 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/28may2020/17971.json
# 32 L-nodes to check
# Opening ./qt30_error_finding/ova3_episode_maps/28may2020/17966.json
# 51 L-nodes to check

# %%
# 2) Hack fixes
for i, ep in enumerate(ep_names):
    print(f"\n=== Episode {ep} ({i+1}/30)===")
    maps  = glob(f'./qt30_error_finding/ova3_systemic_fix/{ep}/*.json')
    if not os.path.exists(f'./qt30_error_finding/ova3_patch_fix/{ep}'):
        os.makedirs(f'./qt30_error_finding/ova3_patch_fix/{ep}')

    for mapfile in maps:
        print(os.path.basename(mapfile))
        with open(mapfile) as f:
            xaif = json.loads(f.read())
        # xaif = xaif_toolbox.remove_all_meta(xaif)

        xaif['text'] = re.sub('\[DONE\]', '', xaif['text'])
        xaif['text'] = re.sub('--', '--.', xaif['text'])

        # Hacky individual fixes for dodgy maps    
        # Main text fixes
        if os.path.basename(mapfile) == '20880.json':
            xaif['text'] = re.sub('Andrew Unknown', 'Andrew Davies', xaif['text'])
        elif os.path.basename(mapfile) == '18798.json':
            faulty_node = [n for n in xaif['AIF']['nodes'] if n['nodeID'] == "125_18798"][0]
            faulty_node.update({'text' : re.sub('Fiona Bruce', 'George Mpanga', faulty_node['text'])})
        elif os.path.basename(mapfile) == '25556.json':
            xaif['text'] = re.sub('\[DONE\]' ,'', xaif['text'])
        elif os.path.basename(mapfile) == '23603.json':
            xaif['AIF']['nodes'] == [n for n in xaif['AIF']['nodes'] if n['text'] != "he said nothing"]
            xaif['text'] = "Rosie Jones [0:15:19]" + xaif['text']
        elif os.path.basename(mapfile) == '23594.json':
            xaif['text'] = "Minette Batters [0:13:30]" + xaif['text']
        elif os.path.basename(mapfile) == '22954.json':
            xaif['text'] = "Fiona Bruce" + xaif['text']
        elif os.path.basename(mapfile) == '19757.json':
            xaif['text'] = re.sub('\[Sue\]:', 'Sue Unknown[00:30:56]', xaif['text'])
            xaif['text'] = re.sub('\[Dave\]:', 'Dave Unknown[00:31:07]', xaif['text'])
            xaif['text'] = re.sub('\[DONE\]', '', xaif['text'])
        elif os.path.basename(mapfile) == '23440.json':
            xaif['text'] = re.sub('\[James\]:', 'James Allcock[00:49:48]', xaif['text'])
        elif os.path.basename(mapfile) == '19750.json':
            xaif['text'] = re.sub('\[Colette\]:', 'Colette Unknown[00:12:31]', xaif['text'])
            xaif['text'] = re.sub('Anneleise', 'Anneliese', xaif['text'])
            xaif['text'] = re.sub('\[Speaker\]', 'Anneliese Dodds[00:13:16]', xaif['text'])
        elif os.path.basename(mapfile) == '19747.json':
            # xaif['text'] = re.sub('\[Bethany\]: I think', 'Bethany Unknown[00:26:48] I think', xaif['text'])
            xaif['text'] = re.sub('\[Bethany\]:&nbsp;I think', 'Bethany Unknown[00:26:48] I think', xaif['text'])
            xaif['text'] = re.sub('\[Bethany\]:&nbsp;<span class=\"highlighted\" id=\"node78_19747\">No', 'Bethany Unknown[00:27:09]&nbsp;<span class=\"highlighted\" id=\"node78_19747\">No', xaif['text'])
            xaif['text'] = re.sub('\[Bethany\]:&nbsp;<span class=\"highlighted\" id=\"node109_19747\">Yes', 'Bethany Unknown[00:27:18]&nbsp;<span class=\"highlighted\" id=\"node109_19747\">Yes', xaif['text'])
            xaif['text'] = re.sub("s --", 's --.', xaif['text']) # hacky
        elif os.path.basename(mapfile) == '19771.json':
            xaif['text'] = re.sub('\[Andrea\]:', 'Andrea Unknown[00:55:09]', xaif['text'])
        elif os.path.basename(mapfile) == '19764.json':
            xaif['text'] = re.sub('\[Josh\]:', 'Josh Unknown[00:40:48]', xaif['text'])
            xaif['text'] = re.sub('\[James\]:', 'James Unknown[00:41:29]', xaif['text'])
        elif os.path.basename(mapfile) == '19772.json':
            xaif['text'] = re.sub('\[James\]:', 'James Unknown[00:59:36]', xaif['text'])
        elif os.path.basename(mapfile) == '19769.json':
            xaif['text'] = re.sub('\[Nicola\]:', 'Nicola Unknown[00:43:15]', xaif['text'])
        elif os.path.basename(mapfile) == '19753.json':
            xaif['text'] = re.sub('\[Andrea\]', 'Andrea Unknown[00:11:35]', xaif['text'])
            xaif['text'] = re.sub('Audience Member', 'Audience Unknown', xaif['text'])
        elif os.path.basename(mapfile) == '19749.json':
            xaif['text'] = re.sub('\[George\]:', 'George Unknown [00:32:13]', xaif['text'])
        elif os.path.basename(mapfile) == '19739.json':
            xaif['text'] = re.sub('Part 1', '', xaif['text'])
        elif os.path.basename(mapfile) == '19774.json':
            xaif['text'] = re.sub('\[Colette\]:', 'Colette Unknown[00:52:15]', xaif['text'])
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Collette' in n['text']]
            for n in faulty_nodes:
                n['text'] = re.sub('Collette', 'Colette Unknown', n['text'])
        elif os.path.basename(mapfile) == '19763.json':
            xaif['text'] = re.sub('\[Speaker\]', 'Unknown Speaker[00:38:55]', xaif['text'])
        elif os.path.basename(mapfile) == '19759.json':
            xaif['text'] = re.sub('\[Alex\]:', 'Alex Unknown[00:41:53]', xaif['text'])
        elif os.path.basename(mapfile) == '19755.json':
            xaif['text'] = re.sub('\[Speaker\]:', 'Nadhim Zahawi[00:35:03]', xaif['text'])


        # Node text fixes
        elif os.path.basename(mapfile) == '18760.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if n['type'] == 'L']
            for n in faulty_nodes:
                n.update({'text': re.sub('Female Audience[\s]*Member1', 'Kirsty Unknown', n['text'])})
                print('updating')
        elif os.path.basename(mapfile) == '18812.json':
            faulty_node = [n for n in xaif['AIF']['nodes'] if n['nodeID'] == "171_18812"][0]
            faulty_node.update({'text' : re.sub('Female Audience[\s]*Member', 'Emma Stephenson', faulty_node['text'])})
            print(faulty_node)
        elif os.path.basename(mapfile) == '25554.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Unknown Unknown' in n['text']]
            for n in faulty_nodes:
                n.update({'text' : re.sub('Unknown Unknown', 'Unknown Speaker', n['text'])})
        elif os.path.basename(mapfile) == '21270.json':
            xaif['text'] = re.sub('Lias ', 'Lisa ', xaif['text'])
        elif os.path.basename(mapfile) == '21305.json':
            faulty_node = [n for n in xaif['AIF']['nodes'] if n['nodeID'] == "21_21305"][0]
            faulty_node['text'] = "Andi Unknown : " + faulty_node['text']
        elif os.path.basename(mapfile) == '21281.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Tim Unknown' in n['text']]
            for n in faulty_nodes:
                n['text'] = re.sub('Tim Unknown', 'Tim Down', n['text'])
        elif os.path.basename(mapfile) == '18848.json':
            for n in xaif['AIF']['nodes']:
                if (n['type'] == 'L') and ('Berlinda' in n['text']):
                    n['text'] = re.sub('Berlinda', 'Belinda', n['text'])
        elif os.path.basename(mapfile) == '18849.json':
            for n in xaif['AIF']['nodes']:
                if (n['type'] == 'L') and ('Deborah Unknown' in n['text']):
                    n['text'] = re.sub('Deborah Unknown', 'Deborah Norrish', n['text'])
        elif os.path.basename(mapfile) == '23820.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Mehdi Hasan' in n['text']]
            for n in faulty_nodes:
                n['text'] = re.sub('Mehdi Hasan', 'Nelufar Hedayat', n['text'])
        elif os.path.basename(mapfile) == '19737.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Suan Desouza' in n['text']]
            for n in faulty_nodes:
                n['text'] = re.sub('Suan', 'Susan', n['text'])



        # Node type fixes
        elif os.path.basename(mapfile) == '18809.json':
            faulty_node = [n for n in xaif['AIF']['nodes'] if n['nodeID'] == '38_18809'][0]
            faulty_node.update({'type': 'I'})
        elif os.path.basename(mapfile) == '23607.json':
            faulty_node = [n for n in xaif['AIF']['nodes'] if n['nodeID'] == "209_23607"][0]
            faulty_node.update({'type': 'I'})
        elif os.path.basename(mapfile) == '21306.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if n['nodeID'] in ["125_21306", "127_21306"]]
            for n in faulty_nodes:
                n['text'] = "Asserting"
                n['type'] = "YA"

        # Wrong reported speech
        elif os.path.basename(mapfile) == '23154.json': 
            # flip edges
            faulty_edges = [e for e in xaif['AIF']['edges'] if e['edgeID'] in [10, 11, 71, 70, 77, 78]]
            for e in faulty_edges:
                e.update({'fromID': e['toID'], 'toID': e['fromID']})

            # flip types
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if n['nodeID'] in ['40_23154', '36_23154', '146_23154', '83_23154', '123_23154', '117_23154']]
            for n in faulty_nodes:
                if n['type'] == 'L':
                    n.update({'type': 'I'})
                elif n['type'] == 'I':
                    n.update({'type': 'L'})
        
        elif os.path.basename(mapfile) == '23602.json': 
            # flip edges
            faulty_edges = [e for e in xaif['AIF']['edges'] if e['edgeID'] in [69, 68]]
            for e in faulty_edges:
                e.update({'fromID': e['toID'], 'toID': e['fromID']})

            # flip types
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if n['nodeID'] in ['94_23602', '88_23602']]
            for n in faulty_nodes:
                if n['type'] == 'L':
                    n.update({'type': 'I'})
                elif n['type'] == 'I':
                    n.update({'type': 'L'})


        # Multiple fixes
        elif os.path.basename(mapfile) == '18790.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Female Audience Member 3 :' in n['text']]
            for n in faulty_nodes:
                n.update({'text' : re.sub('Female Audience Member 3', 'Katie Unknown', n['text'])})
            xaif['text'] = re.sub('Katie\[', 'Katie Unknown[', xaif['text'])
        elif os.path.basename(mapfile) == '18866.json':
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'Mike Maleaudience' in n['text']]
            for n in faulty_nodes:
                n.update({'text' : re.sub('Mike Maleaudience', 'Mike Unknown', n['text'])})
            xaif['text'] = re.sub('Mike\[', 'Mike Unknown[', xaif['text'])
        
        elif os.path.basename(mapfile) == '19756.json':
            # Fix text
            xaif['text'] = re.sub('\[Jim\]', 'Jim Unknown[00:29:52]', xaif['text'])
            xaif['text'] = re.sub('\[DONE\]', '', xaif['text'])
            xaif['text'] = re.sub('\[James\]', 'James Unknown[00:30:32]', xaif['text'])

            # Fix James nodes
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if 'James ' in n['text']]
            for n in faulty_nodes:
                n.update({'text' : re.sub(r'James[\s]*:', 'James Unknown :', n['text'])})

            # Fix Jim nodes
            faulty_nodes = [n for n in xaif['AIF']['nodes'] if n['nodeID'] in ['40_19756', '47_19756', '54_19756', '69_19756', '80_19756']]
            for n in faulty_nodes:
                n.update({'text': re.sub('Fiona Bruce', 'Jim Unknown', n['text'])})


        elif os.path.basename(mapfile) == '21280.json':
            # Remove double name
            faulty_node = [n for n in xaif['AIF']['nodes'] if 'Tony Unkown : Tony Unkown :' in n['text']][0]
            faulty_node['text'] = re.sub('Tony Unkown : Tony Unkown :', 'Tony Unkown :', faulty_node['text'])
            
            # Fix L-nodes
            for n in [n for n in xaif['AIF']['nodes'] if n['type'] == 'L']:
                n.update({'text': re.sub('Tony Unkown', 'Tony Unknown', n['text'])})
        

        elif os.path.basename(mapfile) == '22947.json':
            aif_edges = [e for e in xaif['AIF']['edges'] if e['edgeID'] != 55]
            xaif['AIF']['edges'] = aif_edges
            ova_edges = [e for e in xaif['OVA']['edges'] if not (e['fromID'] == "61_22946" and e['toID'] == "60_22946")]
            xaif['OVA']['edges'] = ova_edges

        # Misc: duplicates
        elif os.path.basename(mapfile) == '23597.json':
            # Remove all duplicate nodes
            seen = []
            new_nodelist = []
            for node in xaif['AIF']['nodes']:
                t = tuple(node.items())
                if t not in seen:
                    seen.append(t)
                    new_nodelist.append(node)
            xaif['AIF']['nodes'] = new_nodelist

            # Remove all duplicate edges
            # only check to/from IDs, edge IDs of duplicates are unique
            seen = []
            new_edgelist = []
            for edge in xaif['AIF']['edges']:
                t = tuple([edge['fromID'], edge['toID']])
                if t not in seen:
                    seen.append(t)
                    new_edgelist.append(edge)
            xaif['AIF']['edges'] = new_edgelist

        # just too much wrong with this one...
        elif os.path.basename(mapfile) == '19761.json':
            continue

        with open(f'./qt30_error_finding/ova3_patch_fix/{ep}/{os.path.basename(mapfile)}', 'w') as f:
            json.dump(xaif, f, indent=4)
        # print()
# Out:
# === Episode 11november2021 (1/30)===
# 23515.json
# 23503.json
# 23485.json
# 23688.json
# 23488.json
# 23484.json
# 23555.json
# 23502.json
# 23514.json
# 23509.json
# 23460.json
# 23476.json
# 23513.json
# 23505.json
# 25691.json
# 23483.json
# 23495.json
# 23494.json
# 25690.json
# 23504.json
# 24042.json
# 23512.json
# 25409.json
# 23498.json
# 23508.json
# 23497.json
# 23478.json
# 23481.json
# 23507.json
# 23511.json
# 23510.json
# 23506.json
# 23480.json
# 23496.json
# 23479.json
# 23475.json
# 23491.json
# 23487.json
# 23517.json
# 23473.json
# 23500.json
#
# === Episode 28october2021 (2/30)===
# 23542.json
# 23578.json
# 23581.json
# 23539.json
# 23558.json
# 23523.json
# 23574.json
# 23580.json (14/58)
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# Node 141_23580 found in text but no node 141_23580 found in node list
# 23579.json (15/58)
# 23548.json (16/58)
# 23525.json (17/58)
# 23572.json (18/58)
# 23533.json (19/58)
# 23544.json (20/58)
# 23552.json (21/58)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[10], line 8
#       6 with open(map_file) as f:
#       7     xaif = json.loads(f.read())
# ----> 8 results = papa.all_analytics(xaif)
#
# File ~/GitHub/papa/src/papa.py:49, in all_analytics(xaif, node_level, speaker, forecast)
#      47 global_analytic_list = []
#      48 global_analytic_list.append(analytics.map_wordcount(xaif))
# ---> 49 global_analytic_list.append(analytics.loc_counts(xaif, speaker=False))
#      50 global_analytic_list.append(analytics.arg_word_densities(xaif, speaker=False))
#      51 global_analytic_list.append(analytics.arg_loc_densities(xaif, speaker=False))
#
# File ~/GitHub/papa/src/analytics.py:154, in loc_counts(xaif, speaker, verbose)
#     152 def loc_counts(xaif, speaker=False, verbose=False):
#     153     if 'AIF' in xaif.keys():
# --> 154         all_nodes, said = ova3.xaif_preanalytic_info_collection(xaif)
#     155     else:
#     156         all_nodes, _ = ova2.xaif_preanalytic_info_collection(xaif)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:574, in xaif_preanalytic_info_collection(xaif, verbose)
#     571 all_nodes = node_setup(xaif)
#     572 all_nodes = add_edge_info(xaif, all_nodes)
# --> 574 all_nodes, said = add_speakers(all_nodes, verbose=verbose)
#     575 all_nodes = add_assumed_speakers(all_nodes)
#     576 all_nodes = add_agreement(all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:335, in add_speakers(all_nodes, verbose)
#     329                     all_nodes[ya_out]['introby'].append(all_nodes[n]['nodeID'])
#     330 # Reported speech: I-node should be attributed to the quoting speaker
#     331
#     332
#     333 else:
#     334     # Get quoting speaker
# --> 335     quoter = reporting_speaker(n, all_nodes)
#     337     for e_out in all_nodes[n]['eout']:
#     338         if all_nodes[e_out]['type'] == 'YA':
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
#     [... skipping similar frames: reporting_speaker at line 154 (2966 times)]
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:133, in reporting_speaker(l_node_id, all_nodes)
#     132 def reporting_speaker(l_node_id, all_nodes):
# --> 133     quoting_ya = [n for n in all_nodes[l_node_id]['ein'] if all_nodes[n]['type'] == 'YA']
#     135     # No incoming YA to this node, or the YA is Analysing: this was the original locution so should return this spkr
#     136     if len(quoting_ya) == 0 or 'Analysing' in [all_nodes[q]['text'] for q in quoting_ya]:
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# Example error in 23552.json (file in 28october2021)
#
# ```
# File ~/GitHub/papa/src/xaif_toolbox.py:574, in xaif_preanalytic_info_collection(xaif, verbose)
#     571 all_nodes = node_setup(xaif)
#     572 all_nodes = add_edge_info(xaif, all_nodes)
# --> 574 all_nodes, said = add_speakers(all_nodes, verbose=verbose)
#     575 all_nodes = add_assumed_speakers(all_nodes)
#     576 all_nodes = add_agreement(all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:335, in add_speakers(all_nodes, verbose)
#     329                     all_nodes[ya_out]['introby'].append(all_nodes[n]['nodeID'])
#     330 # Reported speech: I-node should be attributed to the quoting speaker
#     331
#     332
#     333 else:
#     334     # Get quoting speaker
# --> 335     quoter = reporting_speaker(n, all_nodes)
#     337     for e_out in all_nodes[n]['eout']:
#     338         if all_nodes[e_out]['type'] == 'YA':
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
#     [... skipping similar frames: reporting_speaker at line 154 (2966 times)]
#
# File ~/GitHub/papa/src/xaif_toolbox.py:154, in reporting_speaker(l_node_id, all_nodes)
#     151 if len(ya_anchor) > 1:
#     152     print(f"Multiply-anchored YA {quoting_ya}: anchored by ", *ya_anchor)
# --> 154 return reporting_speaker(ya_anchor[0], all_nodes)
#
# File ~/GitHub/papa/src/xaif_toolbox.py:133, in reporting_speaker(l_node_id, all_nodes)
#     132 def reporting_speaker(l_node_id, all_nodes):
# --> 133     quoting_ya = [n for n in all_nodes[l_node_id]['ein'] if all_nodes[n]['type'] == 'YA']
#     135     # No incoming YA to this node, or the YA is Analysing: this was the original locution so should return this spkr
#     136     if len(quoting_ya) == 0 or 'Analysing' in [all_nodes[q]['text'] for q in quoting_ya]:
#
# RecursionError: maximum recursion depth exceeded
# ```
#
# There's an error in the file, as this kind of cycle shouldn't exist: L-node with edge to a YA-node, and that YA with an edge back the same L.
